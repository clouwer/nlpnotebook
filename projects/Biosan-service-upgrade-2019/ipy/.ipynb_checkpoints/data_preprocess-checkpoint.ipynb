# %% [markdown]
# ## 数据预处理
#
# 计划达到几个目的：
# 1. 提取有用字段
# 2. 数据去重
# 2. 插补缺失项
# 3. 将数据按仪器类型分开
# 4. 分类特征合并
# 4. 文本数据正则化
# 4. ETL后样本存入数据库

# %% [markdown]
# ### 数据读取

# %%
import pandas as pd
import numpy as np

import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
warnings.simplefilter('ignore')

import sys
sys.path.extend(['../src/'])

from config import *

import matplotlib.pyplot as plt
import seaborn as sns

from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

% matplotlib inline

config = Config()

data = {}
for file in ['2015-2018维修数据_部分.xlsx', '2017维修数据.xlsx', '2018维修数据.xlsx']:
    data[file] = pd.read_excel('{}{}'.format(config.origin_data_filepath, file))

data_ = pd.concat(data).reset_index(drop = True)[data['2015-2018维修数据_部分.xlsx'].columns]

# %% [markdown]
# ### 提取有用字段、分类特征合并

# %% [markdown]
# #### 紧急程度字段
#
# 紧急程度这个字段为我们提供的信息是故障问题的定义
# 即什么样的部件故障是可以被评价为紧急故障
#
# 一种处理方式是紧急重要合并，其他全部当成正常。但是必存在很多偏差，
# 而且这列的缺失率较大。这部分信息尽量使用其他特征提取得出
# 最好的方式应该是，通过一部分样本定义哪些部件故障是紧急故障，然后其他同类故障样本用这个模式插补。

# %%
data_['紧急程度'].value_counts()
# Out:
# 正常       1560
# 紧急        841
# 一般        680
# 无要求       587
# 重要        400
# 1个工作日     207
# 2个工作日     136
# 3个工作日      37
# 郭帅          2
# 王老师         1
# 潘婷          1
# Name: 紧急程度, dtype: int64

# %%
data_.loc[-data_['紧急程度'].isin(['正常', '紧急', '重要', '无要求']), '紧急程度'] = '未知'

# %%
data_['紧急程度'].value_counts()
# Out:
# 未知     4445
# 正常     1560
# 紧急      841
# 无要求     587
# 重要      400
# Name: 紧急程度, dtype: int64

# %% [markdown]
# #### 维修服务内容

# %%
service_content = {'维修':'维修', '仪器故障处理':'维修', '更换配件':'维修', 
                   '仪器维护保养':'维护保养', '维护':'维护保养', '年度维护':'维护保养',
                   '项目例行巡检':'巡检','巡检':'巡检',
                   '设备性能验证':'性能验证','性能验证':'性能验证',
                   '移机':'装机/移机', '搬迁':'装机/移机','搬迁调试':'装机/移机','装机调试':'装机/移机','装机调试':'装机/移机',
                   '软件问题处理':'其他','数据分析':'其他','试剂盒性能验证':'其他'}

data_['维修服务内容'] = data_['维修服务内容'].replace().map(service_content)

data_['维修服务内容'].fillna('待确认', inplace = True)

# %% [markdown]
# #### 设备编号

# %%
data_['设备编号'].isnull().sum()
# Out:
# 916

# %% [markdown]
# 设备编号有916个缺失，观察对应设备编号的其他信息
# 可以看到对应的编号也是缺失的
# 可以看到大多是时间较早的样本，缺失过多
# 这种情况只能通过客户名称来对应仪器型号把这个缺失值插补掉

# %% [markdown]
# ##### 设备编号统计

# %%
data_equip = data_.drop_duplicates(subset = '设备编号', keep = 'last')

pd.options.display.max_rows = 1200
data_equip['装机日期'] = pd.to_datetime(data_equip['装机日期'], errors = 'coerce')

# data_equip[['客户名称', '设备编号', '设备型号', '主机序列号','装机日期']].sort_values(by = '客户名称')

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://%s:%s@%s:3306/%s?charset=utf8' %(config.sql_user, config.sql_password, config.sql_ip, config.sql_database),echo = False)
data_equip[['客户名称', '设备编号', '设备型号', '主机序列号','装机日期']].sort_values(by = '客户名称').to_sql('equipment_id', engine, if_exists='replace',index= False)

# %% [markdown]
# 可以看到设备型号的原始数据里有些模块如1296-003可能是其他大仪器的小部件，存在标记不明确的问题，不利于我们按照设备对数据分类，需要与维修工程师沟通让他们补充修正这部分信息

# %% [markdown]
# 还有一个思路是，观察到设备编号的抬头一共有几种：
#
# BS应该是博圣，PE是PE公司
# 设备编号和设备型号没准有某种对应关系

# %% [markdown]
# 另外观察设备编号可以看到，编号并不是完全连续的，比如有BS-2004-PKI-VD-02却没见到BS-2004-PKI-VD-01，这有多种可能性，有可能是这台仪器没有对应的维修报告，顺便维护，没有大修。也有可能是早期就已经淘汰，这一问题在我们定义每台仪器现在的状态的时候，是很必要的。

# %% [markdown]
# 定义设备型号是要解决几个问题：
# 1. 存在部分样本设备型号缺失的情况，这部分缺失型号的样本对应的是哪台仪器
# 2. 计划模型的结果为预测下一次仪器维护的时间，需要将训练样本对仪器做分类，设备型号定义了这一分类

# %% [markdown]
# #### 日期时间处理
#
# 1. 问题发现日期和解决日期是全的，但是服务小时跟上门日期有关，这部分是未知的
# 2. 缺失了服务小时的样本跟设备编号的缺失是对应的，这部分数据插补较困难，属于下一步的工作，可以先做设备编号全的数据

# %%
import missingno as msno
msno.matrix(data_[['设备编号','问题发现日期', '装机日期', '服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# ##### 装机日期

# %%
zjrq_dict = data_equip['装机日期']
zjrq_dict.index = data_equip['设备编号']
zjrq_dict = zjrq_dict.to_dict()

data = data_.loc[data_['设备编号'].notnull(),:].reset_index(drop = True)

data['装机日期'] = data['设备编号'].map(zjrq_dict)

# %% [markdown]
# 可以看到使用设备编号的映射来插补装机日期时，也没有多少的改进，大部分缺失的依然是缺失的

# %%
msno.matrix(data[['设备编号','问题发现日期', '装机日期','服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# 接下来用解决日期和上门日期来修正服务小时
#
# 可以看到缺失的条数并不多，并且能被插补的也并不多

# %% [markdown]
# ##### 服务工时
#
# 用来衡量问题的解决难度

# %%
data.loc[5162,'服务工时(小时)'] = 1
data.loc[6123,'服务工时(小时)'] = 3
data.loc[6124,'服务工时(小时)'] = 0.5
data.loc[6427,'服务工时(小时)'] = 4
data.loc[6721,'服务工时(小时)'] = 3
data.loc[6842,'服务工时(小时)'] = 5.5

# %% [markdown]
# ##### 服务间隔
#
# 用来衡量这个问题的紧急程度，问题可能导致第二天就无法做实验的就会立即派工程师去
# 这个特征跟客户的重要程度和到客户的距离可能会有关，可以研究一下
#
# 还能发现一些脏数据的位置

# %% [markdown]
# 问题发现日期很多是瞎填的，作为绩效考核指标，所以他们通常会填写上门日期的前几天，所以并不一定是准确的，只能作为参考
# 服务单号的日期编码是自动生成的，和报告提交日期一致

# %%
data['服务间隔天数'] = (pd.to_datetime(data['上门日期'], errors = 'coerce') - pd.to_datetime(data['问题发现日期'], errors = 'coerce')).apply(lambda x: x.days)

# %% [markdown]
# ##### 上次维修时间
#
# 对于一台设备，上一次维修时间是被记录的，如果只有一条记录，就登记为空

# %%
from tqdm import tqdm_notebook

data['上次维修时间'] = data['问题发现日期'].copy()
def last_service(x):
    del x[-1]
    x.insert(0, None)
    return x
for equipment_id in tqdm_notebook(data['设备编号'].unique()):
    cache = list(data.loc[data['设备编号'] == equipment_id, '问题发现日期'])
    if len(cache) <= 1:
        data.loc[data['设备编号'] == equipment_id, '上次维修时间'] = None
    else:
        data.loc[data['设备编号'] == equipment_id, '上次维修时间'] = last_service(cache)
# Out:
# HBox(children=(IntProgress(value=0, max=1189), HTML(value='')))

# %%
msno.matrix(data[['设备编号','问题发现日期','上次维修时间', '装机日期','服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# 由于很多仪器是刚装的，第一次维修，所以装机日期来替代上次维修时间是合理的
# 需要考虑的是，第一次新机其实对于相同的问题来说，新机应该是更难坏的，需要留一个标签记录

# %%
data['问题发现日期'].min()
# Out:
# Timestamp('2016-06-30 00:00:00')

# %%
data['装机日期'] = pd.to_datetime(data['装机日期'], errors = 'coerce')

data.loc[(data['上次维修时间'].isnull())&(data['装机日期'] > '2016-06-30'),'上次维修时间'] = data.loc[(data['上次维修时间'].isnull())&(data['装机日期'] > '2016-06-30'),'装机日期']

# %%
msno.matrix(data[['设备编号','问题发现日期','上次维修时间', '装机日期','服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# #### 文本处理

# %%
import re

def text_clean(content):
    try:
#         result = re.sub(r'[^\u4e00-\u9fa5,A-Za-z0-9]', " ",content)
        result = re.sub('&nbsp;', "",content)
        result = re.sub('<br>', "",result)
        result = re.sub(' ', "",result)
#         result = re.sub('正常', " ",result)
        result = re.sub('\n', "",result)
        result = re.sub('\t', "",result)
    except:
        result = ''
    return result

# %%
for col in ['问题描述', '故障描述','服务报告','解决方案','实际问题描述']:
    data[col] = data[col].apply(text_clean)

# %% [markdown]
# 电脑故障不属于定期维护范围之内，后期可以不做考虑。如serverBusy问题

# %% [markdown]
# 可以看到问题描述，故障描述，实际问题描述有重复的部分，服务报告解决方案可能也有重复的部分

# %% [markdown]
# ##### 文本去重 余弦相似性

# %%
from jieba import analyse
jieba.load_userdict('../source/words/userdict.txt')

def words2vec(words1=None, words2=None):
    """
    通过分词、计算并集、词频，得出词频向量
    :param words1:
    :param words2:
    :return: 词频的向量
    """
    v1 = []
    v2 = []
    tag1 = analyse.extract_tags(words1, withWeight=True)
    tag2 = analyse.extract_tags(words2, withWeight=True)
    tag_dict1 = {i[0]: i[1] for i in tag1}
    tag_dict2 = {i[0]: i[1] for i in tag2}
    merged_tag = set(tag_dict1.keys()) | set(tag_dict2.keys())
    for i in merged_tag:
        if i in tag_dict1:
            v1.append(tag_dict1[i])
        else:
            v1.append(0)
        if i in tag_dict2:
            v2.append(tag_dict2[i])
        else:
            v2.append(0)
    return v1, v2

def cosine_similarity(vector1, vector2):
    """
    余弦值相似度计算
    :param vector1:
    :param vector2:
    :return:
    """

    dot_product = 0.0
    norm1 = 0.0
    norm2 = 0.0
    for a, b in zip(vector1, vector2):
        dot_product += a * b
        norm1 += a ** 2
        norm2 += b ** 2
    if norm1 == 0.0 or norm2 == 0.0:
        return 0
    else:
        return round(dot_product / ((norm1 ** 0.5) * (norm2 ** 0.5)) * 100, 2)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\KENSHI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.651 seconds.
# Prefix dict has been built succesfully.

# %%
_data = data.copy()

from tqdm import trange

def cosine_calculator(_data, col1, col2):
    cosine_sim = []
    for i in range(_data.shape[0]):
        w2v1, w2v2 = words2vec(_data[col1][i],_data[col2][i])
        cosine_sim.append(cosine_similarity(w2v1,w2v2))
    return cosine_sim 

def text_col_len(series):
    return series.apply(lambda x: len(x))

def text_concat(data, cut_value, col1, col2):
    _data = data.copy()
    cosine_sim = cosine_calculator(_data, col1, col2)
    _data['cosine_sim'] = cosine_sim
    _data['{}_len'.format(col1)] = text_col_len(_data[col1])
    _data['{}_len'.format(col2)] = text_col_len(_data[col2])
    _data['output'] = None
    _data.loc[_data['cosine_sim'] <=cut_value, 'output'] = _data.loc[_data['cosine_sim'] <=cut_value, col1] + _data.loc[_data['cosine_sim'] <cut_value,col2]
    _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] >= _data['{}_len'.format(col2)]), 'output'] = _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] >= _data['{}_len'.format(col2)]),col1]
    _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] < _data['{}_len'.format(col2)]), 'output'] = _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] < _data['{}_len'.format(col2)]),col2]
    return _data['output']

_data['问题汇总1'] = text_concat(_data, 85, '问题描述', '故障描述')
_data['问题汇总'] = text_concat(_data, 85, '问题汇总1', '实际问题描述')

data['问题汇总'] = _data['问题汇总'].copy()
data['解决方案汇总'] = text_concat(data, 85, '服务报告','解决方案')

# %% [markdown]
# ### 提取有用字段

# %%
data.columns
# Out:
# Index(['服务单号', '客户名称', '所在省份', '客户类型', '客户联系人', '紧急程度', '问题发现日期', '问题发现时间',
#        '服务部门', '事项 ', '项目类别', '分项内容', '工作方式', '问题描述', '派单主管', '分配工程师', '维修总费用',
#        '设备编号', '设备名称', '设备型号', '主机序列号', '装机日期', '维修服务内容', '故障描述', '服务报告',
#        '解决方案', '服务工时(小时)', '上门日期', '上门时间', '解决日期', '解决时间', '总结提交日期', '任务星级',
#        '实际问题描述', '回访时间', '回访对象', '问题是否解决', '总体满意度', '礼仪/形象', '技能水平', '沟通能力',
#        '服务态度', '服务间隔天数', '上次维修时间', '问题汇总', '解决方案汇总'],
#       dtype='object')

# %%
data = data[['服务单号', '客户名称', '客户类型', '紧急程度', '问题发现日期', '分配工程师', 
      '设备编号', '设备型号','服务工时(小时)', '服务间隔天数', '上次维修时间',
      '装机日期', '维修服务内容', '问题汇总', '解决方案汇总']]

# data_.to_sql('etl_data', engine, if_exists='replace',index= False)

# %% [markdown]
# ## 文本挖掘

# %% [markdown]
# 在做完了传统的数据预处理之后，其他的信息就全部含在文本当中了，
# 此时要对文本进行挖掘，提取更多的特征的同时将结构化数据中“待定”和“未知”的缺失信息进行插补

# %%
import pandas as pd
import numpy as np
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
warnings.simplefilter('ignore')
import sys
sys.path.extend(['../src/'])

from config import *
config = Config()

from wordcloud import WordCloud
import jieba
from jieba import analyse
import re
from tqdm import tqdm
from sqlalchemy import create_engine
from config import Config
import os

engine = create_engine('mysql+pymysql://%s:%s@%s:3306/%s?charset=utf8' %(config.sql_user, config.sql_password, config.sql_ip, config.sql_database),echo = False)
sql = "select * from etl_data"
data = pd.read_sql_query(sql, engine)

# %%
data.columns
# Out:
# Index(['服务单号', '客户名称', '客户类型', '紧急程度', '问题发现日期', '分配工程师', '设备编号', '设备型号',
#        '服务工时(小时)', '服务间隔天数', '上次维修时间', '装机日期', '维修服务内容', '问题汇总', '解决方案汇总'],
#       dtype='object')

# %%
pd.DataFrame(data['设备型号'].value_counts())
# Out:
#                       设备型号
# 1235-514              1683
# GSL-120                675
# 2021-0010              594
# 2081-0010              524
# GSL-120/GSL-10         399
# GCS3000DX2             393
# 1235-5220              391
# 1420-020               389
# TQD                    353
# CDS-5                  308
# 1235-501               240
# Capillarys 2 FP        229
# Xevo TQD               126
# Quattro Micro           82
# 6000                    77
# 6000-0010               64
# KM1                     63
# CaptureStation          43
# 1420-012                40
# 1296-026                35
# luminex 200             31
# LX200                   24
# GCS3000Dx2              23
# 00-0335                 23
# UPLC                    20
# KM2                     20
# 1296-0010               19
# 1296-003                12
# 1235-0110                9
# TQS                      5
# 5014-0020                4
# CaptureStation(FISH)     3
# GSL-10                   2
# MB4                      2
# MB8/MB4                  1
# BGI SEQ-500              1
# 1296-071                 1
# Nextseq 550AR            1
# SLAN-96S                 1
# SD                       1

# %% [markdown]
# ### 修正jieba分词

# %%
import jieba.posseg as pseg
jieba.load_userdict('../source/words/userdict.txt')  
# 创建停用词list  
def stopwordslist(filepath):  
    stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]  
    return stopwords    
  
# 对句子进行分词  
def seg_sentence(sentence):  
    sentence_seged = jieba.cut(sentence.strip(), HMM=True, cut_all=False)  
#     sentence_seged = jieba.cut_for_search(sentence.strip(), HMM=True)
    stopwords = stopwordslist('../source/words/中文停用词表.txt')  # 这里加载停用词的路径  
    outstr = ''  
    for word in sentence_seged:  
        if word not in stopwords:  
            if word != '\t':  
                outstr += word  
                outstr += " "  
    return outstr

# %%
jieba.load_userdict('../source/words/userdict.txt')

print(data['解决方案汇总'][12])
print(seg_sentence(data['解决方案汇总'][12]))
# Out:
# 1、查看近几次实验结果，发现标准曲线荧光值均正常，但质控有几次出控的情况，并且在位置上并无规律。判断其与质控品的吸样和后续的反应步奏有关。检查加样针坐标，发现其在质控品和样本架的坐标偏左严重；校准加样针的各坐标。检查洗针槽比较脏，清洁冲洗洗针槽。检查洗板头，与增强液头，发现针尖上均有厚厚一层结晶，可能会导致交叉污染；清洁并清洗洗板机头和增强液头。检查并校准左右加样枪的静态气压。检查检测平台，发现检测平台通光孔位置有较多污染物，清洁清洁检测平台。结果待第二天观察实验结果2、检查ups，发现内部3个风扇均不转了。亮起的红灯表示ups内部温度过高。将仪器电源暂时接到墙上，拆开ups，取下风扇，待第二天到市场去配。第二天：1、当天仪器实验结果质控正常2、将市场采购的ups轴流风扇更换上，ups运行正常。
# 查看 近 几次 实验 发现 标准曲线 荧光值 均 正常 质控 几次 出控 情况 位置 无规律 判断 质控 品 吸样 后续 反应 步奏 检查 加样针 坐标 发现 质控 品 样本架 坐标 偏左 严重 校准 加样针 坐标 检查 洗针 槽 比较 脏 清洁 冲洗 洗针 槽 检查 洗板 头 增强液 头 发现 针尖 均 厚厚 一层 结晶 可能 会 导致 交叉 污染 清洁 清洗 洗板机 头 增强液 头 检查 校准 左右 加样枪 静态 气压 检查 检测 平台 发现 检测 平台 通光孔 位置 污染物 清洁 清洁 检测 平台 第二天 观察 实验 检查 ups 发现 内部 风扇 均 转 亮起 红灯 表示 ups 内部 温度过高 仪器 电源 暂时 接到 墙上 拆开 ups 取 风扇 第二天 市场 去配 第二天 当天 仪器 实验 质控 正常 市场 采购 ups 轴流 风扇 更换 ups 运行 正常

# %%
jieba.load_userdict('../source/words/userdict.txt')

print(data['问题汇总'][17])
print(seg_sentence(data['问题汇总'][17]))
# Out:
# 按计划执行年度维护维护保养
# 按计划 执行 年度维护 维护保养

# %%
jieba.load_userdict('../source/words/userdict.txt')
words = pseg.cut(seg_sentence(data['问题汇总'][13]))
for word, flag in words:
    # 格式化模版并传入参数
    print('%s, %s' % (word, flag))
# Out:
# 客户, n
#  , x
# 反映, v
#  , x
# 120, m
#  , x
# 仪器, n
#  , x
# 漏油, n
#  , x
# 现象, n
#  , x
# 客户, n
#  , x
# 反映, v
#  , x
# 120, m
#  , x
# 油路, n
#  , x
# 严重, a
#  , x
# 漏油, n
#  , x
# 现象, n
#  , x

# %% [markdown]
# ### 特征插补

# %% [markdown]
# #### 紧急程度
#
# 紧急程度这个特征的意义在于帮助我们对问题定性
#
# 方案：通过提取出已有标签的样本做训练，预测缺失的样本再进行调整
# 事实上，很容易出现文本中并不提及重要和紧急的情况

# %%
data_['紧急程度'].value_counts()
# Out:
# 未知     3580
# 正常     1533
# 紧急      836
# 无要求     584
# 重要      384
# Name: 紧急程度, dtype: int64

# %% [markdown]
# 可以看到有3580个样本是未知紧急程度的，无要求这个比较难判断情感色彩，作为正常，不紧急来处理
# 重要和紧急是两类

# %%
def word_cloud_tfidf(data_line, output, save_path):
    data_line_clean = data_line.apply(lambda x: text_clean(x))
    cache = ""
    for i in data_line_clean:
        cache = cache + i
    content = " ".join(jieba.cut(cache))
    key_words = analyse.extract_tags(content, topK=2000, withWeight=True, allowPOS=('nb','n','nr', 'ns','a','ad','an','nt','nz','v','d'))
    textrank = analyse.textrank(content,topK = 200,withWeight = True)
    keywords = dict()
    for i in key_words:
        keywords[i[0]] = i[1]
#     back_coloring = plt.imread(bg_image_path)  # 设置背景图片
    my_wordcloud = WordCloud(
                     background_color = 'white', #背景颜色
                     width=1500,height=960, #图片大小
                     margin=10
                   )
    my_wordcloud.generate_from_frequencies(keywords)
    plt.figure(figsize = (12, 7))
    plt.imshow(my_wordcloud)
    plt.axis("off")
    plt.savefig('{}/{}'.format(save_path, output))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
from wordcloud import WordCloud
import jieba
from jieba import analyse
import re

# %% [raw]
# from data_preprocess import text_clean
#
# word_cloud_tfidf(data.loc[data['紧急程度'] == '紧急', '问题汇总'], '紧急问题', config.savefig_path)

# %% [raw]
# word_cloud_tfidf(data_.loc[data_['紧急程度'] == '重要', '问题汇总'], '重要问题', config.savefig_path)

# %% [raw]
# word_cloud_tfidf(data_.loc[data_['紧急程度'] == '正常', '问题汇总'], '正常问题', config.savefig_path)

# %% [raw]
# word_cloud_tfidf(data_.loc[data_['紧急程度'] == '无要求', '问题汇总'], '无要求问题', config.savefig_path)

# %% [markdown]
# #### 维修服务内容

# %%
data['维修服务内容'].value_counts()
# Out:
# 维修       4017
# 维护保养     1076
# 待确认       979
# 装机/移机     390
# 巡检        340
# 性能验证       83
# 其他         32
# Name: 维修服务内容, dtype: int64

# %%
data_service = data.loc[data['维修服务内容'] == '维修',:]
data_maintain = data.loc[data['维修服务内容'] == '维护保养',:]

# %%
from data_preprocess import text_clean

word_cloud_tfidf(data_service['问题汇总'], '维修词云', config.savefig_path)
word_cloud_tfidf(data_maintain['问题汇总'], '维护词云', config.savefig_path)

# %%
word_cloud_tfidf(data.loc[data['维修服务内容'] == '装机/移机','问题汇总'], '装机词云', config.savefig_path)

# %%
word_cloud_tfidf(data.loc[data['维修服务内容'] == '巡检','问题汇总'], '巡检词云', config.savefig_path)

# %%
word_cloud_tfidf(data.loc[data['维修服务内容'] == '性能验证','问题汇总'], '性能验证词云', config.savefig_path)

# %% [markdown]
# 从维修服务内容的词云中可以看到，除了维修维护字段中存在维护和维修的信息以外，装机巡检和性能验证中，也存在很多维护和维修的内容，所以单纯使用这个字段做是否维护或者维修的划分，是存在很大偏差的。而且还有979个待确认的样本存在。
# 总结可以得出：
# 1. 性能验证、巡检、装机和最终的结果关系较低，是没什么用的信息，这些样本都可以归入待分类
# 2. 单条样本中既存在维修的信息又存在维护的信息，有可能对某几台仪器维修但对另几台仪器维护，这部分信息如何提取是很关键的问题。就这一问题上，需要观察含年度维护字样的样本的形式，提取一定的规则来将维护的时间点提取出来。
# 3. 不错的是，对于单次服务多次修理的记录，很多样本都已经分开了
# 4. 所以对于该仪器来说是可以提出上一次维护的时间点的

# %%
pd.options.display.max_rows = 1000

data.loc[data['维修服务内容'] == '维护保养',['设备编号','问题汇总']].head(100)
# Out:
#                       设备编号                                               问题汇总
# 475     BS-2016-Aff-SMY-07                       上海国妇婴的芯片系统需要上门做季度维护按计划执行季度维护
# 494      BS-2008-PKI-VD-06                   常德市第一医院1420，洗板机维护。1420年度维护、洗板机维护
# 502      BS-2014-PKI-AD-12                                  常德市妇幼1235维护1235维护
# 508      BS-2014-PKI-AD-21                                  宜兴妇幼1235半年度维护年度维护
# 509      BS-2014-PKI-AD-17                                  江阴妇幼1235半年度维护年度维护
# 510      BS-2014-PKI-AD-08                                   苏大附一1235年度维护年度维护
# 511      BS-2004-PKI-VD-05                                   泰州妇幼1420年度维护年度维护
# 513      BS-2003-PKI-VD-08                         无锡妇幼1235半年度维护和1420年度维护年度维护
# 514  BS-2014-PKI-AD-02（回收）                        无锡妇幼1235半年度维护和1420年度维护半年度维护
# 521      BS-2001-PKI-V2-01                         宁波妇儿新筛1235和1420按计划执行维护维护保养
# 542      BS-2012-PKI-AD-06                             鼓楼医院1235半年度维护1235半年度维护
# 543     BS-2013-LAK-GSL-03                                  鼓楼医院120半年度维护半年度维护
# 544      BS-2014-PKI-VD-03                                   镇江妇幼1420年度维护年度维护
# 546      BS-2004-PKI-VD-02                                江苏省人民医院1420年度维护年度维护
# 552      BS-2016-PKI-AD-05  1.17日8:40左右，郑允樵老师来电表示2台1235设备年前需要维护，其中有一台旧的123...
# 553      BS-2015-PKI-AD-07  1.17日8:40左右，郑允樵老师来电表示2台1235设备年前需要维护，其中有一台旧的123...
# 555     BS-2016-PKI-GSP-05                                     邵阳妇幼p9维护P9年度维护
# 576      BS-2013-PKI-AD-19                         120系统重装；1235维护内容：1235年度维护。
# 583      BS-2016-PKI-AD-03                                         1235维护维护保护
# 584     BS-2014-LAK-GSL-09                                            120维护维护
# 585      BS-2015-PKI-AD-03                                 1235、1420、p9维护仪器维护
# 586      EX-2003-PKI-AD-01                                         1235维护维护保养
# 587     BS-2016-PKI-GSP-06                   1235维护；1420维护；gsp季度维护故障：1235年度维护
# 588      BS-2006-PKI-VD-03                   1235维护；1420维护；gsp季度维护故障：1420年度维护
# 589     BS-2016-SBA-CP2-06                       120、1235、km2、cap2、cds5维护地贫维护
# 590      BS-2013-PKI-AD-18                     120、1235、km2、cap2、cds5维护1235维护
# 591      BS-2012-PKI-AD-09                   1235维护；1420维护；gsp季度维护故障：gsp半年度维护
# 593     BS-2015-LAK-GSL-09                      120、1235、km2、cap2、cds5维护120维护
# 594      BS-2008-LAK-KM-06                      120、1235、km2、cap2、cds5维护KM2维护
# 595     BS-2015-TMN-CDS-04                     120、1235、km2、cap2、cds5维护CDS5维护
# 623     BS-2014-TMN-CDS-01                              舟山医院120、cds-5、km2维护维护
# 624     BS-2016-LAK-GSL-03             宁波市第一医院120、cds-5维护维护+仪器偶尔发生扫完片后架子不放回现象
# 625     BS-2015-TMN-CDS-03                               宁波市第一医院120、cds-5维护维护
# 628      BS-2005-PKI-VD-09                       安徽省所两台1235半年度维护，1420年度维护维护保养
# 629      BS-2014-PKI-AD-15                       安徽省所两台1235半年度维护，1420年度维护维护保养
# 630      BS-2011-PKI-AD-06                       安徽省所两台1235半年度维护，1420年度维护维护保养
# 631     BS-2016-TMN-CDS-04                          龙岩第一医院120维护；cds-5维护CDS5维护
# 632     BS-2016-LAK-GSL-11                         龙岩第一医院120维护；cds-5维护120年度维护
# 633      BS-2008-PKI-AD-05                                   富阳妇幼1235维护1235维护
# 636      BS-2014-PKI-AD-22                       怀化妇幼1235维护；1420维护1235和1420维护
# 638      BS-2003-PKI-VD-01                            厦门妇幼1235维护、1420维护1420维护
# 639      BS-2013-PKI-AD-04                            厦门妇幼1235维护、1420维护1235维护
# 640      BS-2014-PKI-AD-19                              杭州妇产科医院两台1235需要维护维护保养
# 641      BS-2007-PKI-AD-01                              杭州妇产科医院两台1235需要维护维护保养
# 660      BS-2012-PKI-VD-03               枣庄妇幼1235半年度维护，1420年度维护，需工程师维护。仪器年度维护
# 661      BS-2012-PKI-AD-11            菏泽妇幼两台1235半年度，1420年度维护、移机，需工程师维护处理。年度维护
# 662      BS-2010-PKI-AD-07            菏泽妇幼两台1235半年度，1420年度维护、移机，需工程师维护处理。年度维护
# 663      BS-2006-PKI-VD-04            菏泽妇幼两台1235半年度，1420年度维护、移机，需工程师维护处理。年度维护
# 664      BS-2011-PKI-AD-02               枣庄妇幼1235半年度维护，1420年度维护，需工程师维护。仪器年度维护
# 666      BS-20XX-PKI-VD-03      烟台山医院120/1420/p9年度维护，1235季度维护，需工程师上门维护。年度维护保养
# 668      BS-2014-PKI-AD-16                     合肥市妇幼保健所1235季度维护到期，需工程师处理。维护保养
# 669      BS-2011-PKI-AD-05      烟台山医院120/1420/p9年度维护，1235季度维护，需工程师上门维护。季度维护保养
# 670      BS-2014-PKI-P9-10      烟台山医院120/1420/p9年度维护，1235季度维护，需工程师上门维护。年度维护保养
# 671     BS-2012-LAK-GSL-04      烟台山医院120/1420/p9年度维护，1235季度维护，需工程师上门维护。年度维护保养
# 672      BS-2015-PKI-AD-14                        安徽省妇保1235季度维护到期，需工程师处理。维护保养
# 673      BS-2014-PKI-AD-06                              岳阳妇幼1235/1420维护1235维护
# 674      BS-2003-PKI-VD-03                              岳阳妇幼1235/1420维护1420维护
# 675      BS-2010-PKI-AD-02                        湖南省妇幼1235年度维护；1420年度维护；季度维护
# 676      BS-2013-PKI-AD-14                                  福州总院1235维护;1235维护
# 687     BS-2012-LAK-GSL-07                                 120维护；km1维护120年度维护
# 688      BS-2008-LAK-KM-05                                 120维护；km1维护KM1年度维护
# 689      BS-2009-PKI-AD-05                              1235/芯片维护内容：1235季度维护。
# 690     BS-2014-Aff-SMY-04                           1235/芯片维护内容：GCS3000年度维护。
# 692     BS-2016-SBA-CP2-01                           两台120维护；地贫维护；cds-5维护地贫维护
# 693     BS-2014-TMN-CDS-06                         两台120维护；地贫维护；cds-5维护CDS5维护
# 694     BS-2016-LAK-GSL-10                          两台120维护；地贫维护；cds-5维护120维护
# 695     BS-2009-LAK-GSL-02                          两台120维护；地贫维护；cds-5维护120维护
# 697      BS-2011-PKI-AD-04                          1420维护1235维护P9维护维护（黄宝加老师）
# 698      BS-2001-PKI-V2-10                          1420维护1235维护P9维护维护（郑发明老师）
# 699     BS-2011-TMN-CDS-02                                        两台cds-5维护维护
# 700     BS-2014-TMN-CDS-02                                        两台cds-5维护维护
# 703     BS-2009-LAK-GSL-01                               济南妇幼GSL120年度维护常规维护保养
# 704     BS-2014-TMN-CDS-07                     青岛妇儿GSL120半年度维护，CDS5年度维护设备年度维护
# 705     BS-2012-LAK-GSL-02                          山大生殖医院两台GSL120半年度维护设备常规维护
# 706     BS-2015-LAK-GSL-04                          山大生殖医院两台GSL120半年度维护设备常规维护
# 711      BS-2011-PKI-VD-02                                  山东省妇幼1420年度维护年度维护
# 713      BS-2001-PKI-V2-06                                   齐鲁医院1420年度维护年度维护
# 720      BS-2013-PKI-AD-09                    济南妇幼新筛1420年度维护，1235状态检查；搬家：年度维护
# 721      BS-2000-PKI-V2-01                    济南妇幼新筛1420年度维护，1235状态检查；搬家：年度维护
# 722     BS-2012-LAK-GSL-03                    青岛妇儿GSL120半年度维护，CDS5年度维护设备半年度维护
# 723     BS-2016-LAK-GSL-06                               济南妇幼GSL120年度维护常规维护保养
# 725      EX-2017-PKI-AD-01  湖北省妇幼的1235有一年半左右的时间未进行维护了，科室老师反映需要对1235进行维护。故障...
# 741     BS-2016-PKI-GSP-08                    gsp开机前仪器检测维护故障：1、gsp年度维护2、gsp升级
# 753     BS-2014-TMN-CDS-06                                  福建省妇幼cds5维护CDS5维护
# 754      BS-2009-PKI-AD-06                               金华市妇幼保健院1235、cds-5维护
# 755      BS-2012-PKI-AD-05                                娄底市妇幼保健院1235、1420维护
# 756      BS-2014-PKI-AD-01                             宁波妇儿新筛1235维护内容：1235维护。
# 768     BS-2015-PKI-GSP-03                                      按计划执行季度维护季度维护
# 769     BS-2015-PKI-GSP-02                                      执行GSP年度维护年度维护
# 776      BS-2013-LAK-KM-03                              台州妇保两台km1、1235维护KM1维护
# 777      BS-2012-LAK-KM-01                              台州妇保两台km1、1235维护KM1维护
# 793     BS-2016-Aff-SMY-03                      湘潭市妇幼1235、芯片维护内容：GCS3000年度维护。
# 798     BS-2016-Aff-SMY-04                      湖南省计划生育研究所芯片维护内容：GCS3000年度维护。
# 828      BS-2013-PKI-P9-02  浙江省儿童医院多台P9、1235、1420维护1、4台P9年度维护2、B仪器经常报错“定义打...
# 829      BS-2015-PKI-AD-06                        邵阳市妇幼1235、1420维护1235、1420维护
# 831     BS-2012-TMN-CDS-01                           宁波市妇儿产筛1235、cds5维护cds5维护
# 832      BS-2011-PKI-AD-08                                 宁波市妇儿产筛1235、cds5维护
# 846      BS-2011-PKI-AD-08  宁波妇幼更换1297维护包；电脑重装系统；更换1号制冷风扇内容：更换1297维护包、1235...
# 853      BS-2009-PKI-AD-03              苏州市立医院两台1235季度、一台1420年度、一套120年度维护维护保养
# 854     BS-2011-LAK-GSL-04              苏州市立医院两台1235季度、一台1420年度、一套120年度维护维护保养

# %% [markdown]
# #### 装机日期
#
# 虽然较难知道装机具体日期，但是可以推测装机的年份和月份

# %%
data.loc[data['装机日期'].isnull(),['设备编号','装机日期']]
# Out:
#                     设备编号 装机日期
# 44     BS-20XX-PKI-WR-03  NaT
# 53    BS-2016-Aff-XDZ-06  NaT
# 60     BS-20XX-PKI-VD-05  NaT
# 61    EX-20XX-LAK-GSL-01  NaT
# 83     EX-20XX-PKI-AD-01  NaT
# 84     EX-20XX-PKI-WS-01  NaT
# 96     BS-20XX-PKI-SK-22  NaT
# 99     BS-20XX-PKI-WR-03  NaT
# 148    BS-20XX-PKI-VD-05  NaT
# 170    EX-20XX-PKI-WS-01  NaT
# 172    BS-20XX-PKI-WR-03  NaT
# 666    BS-20XX-PKI-VD-03  NaT
# 725    EX-2017-PKI-AD-01  NaT
# 741   BS-2016-PKI-GSP-08  NaT
# 796    BS-20XX-PKI-VD-03  NaT
# 977   BS-2016-PKI-GSP-08  NaT
# 1073   EX-20XX-PKI-AD-01  NaT
# 1075  BS-2016-PKI-GSP-08  NaT
# 1146   EX-20XX-PKI-AD-01  NaT
# 1201   EX-20XX-PKI-AD-01  NaT
# 1345   BS-20XX-PKI-WR-03  NaT
# 1347  BS-2016-PKI-GSP-08  NaT
# 1392   BS-20XX-PKI-VD-05  NaT
# 1480   BS-20XX-PKI-SK-30  NaT
# 1496  BS-2016-PKI-GSP-08  NaT
# 1522   BS-20XX-PKI-WR-05  NaT
# 1595   BS-20XX-PKI-WS-10  NaT
# 1644   BS-20XX-PKI-WR-05  NaT
# 1695   BS-20XX-PKI-SK-20  NaT
# 1729   BS-20XX-PKI-WS-04  NaT
# 1862   BS-20XX-PKI-WR-03  NaT
# 1947  BS-2016-PKI-GSP-08  NaT
# 2077   BS-20XX-PKI-WS-03  NaT
# 2209   BS-20XX-PKI-VD-08  NaT
# 2340   BS-20XX-PKI-WS-11  NaT
# 2489   EX-20XX-PKI-AD-01  NaT
# 2496   EX-2017-PKI-AD-01  NaT
# 2497  BS-2016-PKI-GSP-08  NaT
# 2543   EX-2017-PKI-AD-01  NaT
# 2544  BS-2016-PKI-GSP-08  NaT
# 2548   BS-20XX-PKI-WS-22  NaT
# 2618   BS-20XX-PKI-WR-03  NaT
# 2651           TM-GSL-01  NaT
# 2669           TM-GSP-01  NaT
# 2721   BS-20XX-PKI-WS-21  NaT
# 2996   BS-20XX-PKI-VD-03  NaT
# 3055   EX-2017-PKI-AD-01  NaT
# 3071  BS-2016-PKI-GSP-08  NaT
# 3126   BS-20XX-PKI-VD-03  NaT
# 3307  BS-2016-PKI-GSP-08  NaT
# 3403   EX-20XX-PKI-AD-01  NaT
# 3405  BS-2016-PKI-GSP-08  NaT
# 3476   EX-20XX-PKI-AD-01  NaT
# 3531   EX-20XX-PKI-AD-01  NaT
# 3675   BS-20XX-PKI-WR-03  NaT
# 3677  BS-2016-PKI-GSP-08  NaT
# 3722   BS-20XX-PKI-VD-05  NaT
# 3810   BS-20XX-PKI-SK-30  NaT
# 3826  BS-2016-PKI-GSP-08  NaT
# 3852   BS-20XX-PKI-WR-05  NaT
# 3925   BS-20XX-PKI-WS-10  NaT
# 3974   BS-20XX-PKI-WR-05  NaT
# 4025   BS-20XX-PKI-SK-20  NaT
# 4059   BS-20XX-PKI-WS-04  NaT
# 4192   BS-20XX-PKI-WR-03  NaT
# 4277  BS-2016-PKI-GSP-08  NaT
# 4407   BS-20XX-PKI-WS-03  NaT
# 4531      PE-GSP-2017016  NaT
# 4532       PE-AD-2011006  NaT
# 4533       PE-AD-2014015  NaT
# 4534       PE-AD-2014015  NaT
# 4535      PE-PP9-2017002  NaT
# 4536       PE-VT-2005007  NaT
# 4566       PE-AD-2015014  NaT
# 4567       PE-AD-2015014  NaT
# 4568       PE-AD-2015014  NaT
# 4572     LAK-GSL-2018009  NaT
# 4574       PE-AD-2018019  NaT
# 4582       PE-AD-2015012  NaT
# 4583       PE-AD-2015012  NaT
# 4584       PE-VT-2007008  NaT
# 4585       PE-VT-2007008  NaT
# 4586      WTS-QM-2016001  NaT
# 4597       PE-AD-2012002  NaT
# 4598       PE-AD-2012002  NaT
# 4599       PE-VT-2005003  NaT
# 4600      PE-PP9-2016006  NaT
# 4606       PE-AD-2016002  NaT
# 4607       PE-AD-2019002  NaT
# 4608       PE-VT-2008007  NaT
# 4614           TM-GSL-01  NaT
# 4626       PE-AD-2014012  NaT
# 4627       PE-VT-2005004  NaT
# 4628       PE-AD-2014012  NaT
# 4629       PE-AD-2014012  NaT
# 4630       PE-VT-2005004  NaT
# 4631      PE-PP9-2017015  NaT
# 4632     LAK-GSL-2018003  NaT
# 4633       PE-AD-2014012  NaT
# 4646     TMF-GCS-2016007  NaT
# 4647       PE-AD-2016011  NaT
# 4648       PE-AD-2016011  NaT
# 4649       PE-AD-2016011  NaT
# 4650     TMF-GCS-2016007  NaT
# 4651     TMF-GCS-2016007  NaT
# 4652       PE-VT-2011002  NaT
# 4655       PE-AD-2016006  NaT
# 4669      PE-GSP-2017003  NaT
# 4670       PE-VT-2012005  NaT
# 4671      PE-PP9-2017016  NaT
# 4672       PE-AD-2018010  NaT
# 4673       PE-AD-2018010  NaT
# 4680       PE-AD-2013002  NaT
# 4681      PE-GSP-2016011  NaT
# 4682      PE-GSP-2016011  NaT
# 4683      PE-PP9-2016015  NaT
# 4684     LAK-GSL-2016017  NaT
# 4685       PE-AD-2013002  NaT
# 4688       PE-AD-2018016  NaT
# 4692       PE-VT-2012001  NaT
# 4699      PE-GSP-2018004  NaT
# 4700       PE-AD-2013017  NaT
# 4701       PE-VT-2013005  NaT
# 4702      PE-PP9-2016011  NaT
# 4703       PE-AD-2018013  NaT
# 4704       PE-AD-2013017  NaT
# 4705       PE-AD-2018013  NaT
# 4706       PE-VT-2013005  NaT
# 4707      PE-PP9-2016011  NaT
# 4746  SBA-CAP2FP-2016001  NaT
# 4747     WTS-TQD-2015003  NaT
# 4748       LU-LX-2015003  NaT
# 4749     LAK-GSL-2016007  NaT
# 4750       PE-AD-2016003  NaT
# 4751      PE-PP9-2015001  NaT
# 4752       PE-VT-2007012  NaT
# 4753     TMF-GCS-2014005  NaT
# 4754     WTS-TQD-2015003  NaT
# 4755     WTS-TQD-2015003  NaT
# 4756     LAK-GSL-2018004  NaT
# 4757     TMF-GCS-2014005  NaT
# 4758       PE-AD-2016003  NaT
# 4759     LAK-GSL-2016007  NaT
# 4760       PE-AD-2016003  NaT
# 4761     LAK-GSL-2018004  NaT
# 4762     TMF-GCS-2014005  NaT
# 4763     LAK-GSL-2016007  NaT
# 4764     TMF-GCS-2014005  NaT
# 4765     WTS-TQD-2015003  NaT
# 4766     TMF-GCS-2014005  NaT
# 4770       PE-AD-2003001  NaT
# 4771     TMN-CDS-2016011  NaT
# 4772       PE-AD-2003001  NaT
# 4773       PE-AD-2003001  NaT
# 4774       PE-AD-2003001  NaT
# 4775     LAK-GSL-2016004  NaT
# 4776       PE-AD-2018003  NaT
# 4777       PE-AD-2008007  NaT
# 4778       PE-AD-2008007  NaT
# 4779       PE-AD-2018003  NaT
# 4780     LAK-GSL-2016004  NaT
# 4783     LAK-GSL-2014008  NaT
# 4784       PE-AD-2010008  NaT
# 4785     LAK-GSL-2014008  NaT
# 4786  SBA-CAP2FP-2017001  NaT
# 4792       PE-DX-2017005  NaT
# 4793       PE-DX-2017005  NaT
# 4794       PE-DX-2017005  NaT
# 4795       PE-DX-2017005  NaT
# 4796       PE-AD-2018012  NaT
# 4797      LAK-KM-2008001  NaT
# 4798       PE-AD-2018012  NaT
# 4799       PE-AD-2018012  NaT
# 4805       PE-AD-2014017  NaT
# 4806     LAK-GSL-2014001  NaT
# 4807     LAK-GSL-2014001  NaT
# 4808       PE-AD-2014017  NaT
# 4809     LAK-GSL-2014001  NaT
# 4810      LAK-KM-2009007  NaT
# 4811       PE-AD-2014017  NaT
# 4813       PE-VT-2011004  NaT
# 4815       PE-VT-2017001  NaT
# 4816       PE-VT-2017001  NaT
# 4817       PE-VT-2017001  NaT
# 4818      LAK-KM-2018003  NaT
# 4822     WTS-TQD-2016025  NaT
# 4823     WTS-TQD-2015013  NaT
# 4848     LAK-GSL-2010001  NaT
# 4849       PE-AD-2007001  NaT
# 4850     TMN-CDS-2015007  NaT
# 4851     LAK-GSL-2018005  NaT
# 4852       PE-AD-2014018  NaT
# 4853     LAK-GSL-2018005  NaT
# 4854       PE-AD-2014018  NaT
# 4857       PE-AD-2008005  NaT
# 4858       PE-AD-2008005  NaT
# 4859       PE-AD-2015008  NaT
# 4860       PE-AD-2015008  NaT
# 4875     WTS-TQD-2014009  NaT
# 4876       PE-AD-2017010  NaT
# 4877       PE-AD-2014016  NaT
# 4878       PE-VT-2007011  NaT
# 4879      PE-PP9-2014012  NaT
# 4880      PE-GSP-2017012  NaT
# 4881      PE-GSP-2017012  NaT
# 4882     WTS-TQD-2016015  NaT
# 4883     WTS-TQD-2014009  NaT
# 4884     WTS-TQD-2016015  NaT
# 4885     WTS-TQD-2014009  NaT
# 4886     WTS-TQD-2016015  NaT
# 4887      PE-GSP-2017012  NaT
# 4888      PE-GSP-2017012  NaT
# 4889     WTS-TQD-2016015  NaT
# 4890     WTS-TQD-2014009  NaT
# 4902    LAK-GSL-20130002  NaT
# 4914      PE-GSP-2018001  NaT
# 4915      PE-GSP-2018001  NaT
# 4916       PE-AD-2012012  NaT
# 4918      LAK-KM-2017003  NaT
# 4919      LAK-KM-2017003  NaT
# 4920     TMN-CDS-2018012  NaT
# 4921   BS-20XX-PKI-WR-03  NaT
# 4926       PE-AD-2016009  NaT
# 4927       PE-VT-2007010  NaT
# 4928      PE-PP9-2017003  NaT
# 4929       PE-AD-2016009  NaT
# 4932   EX-2017-PKI-AD-01  NaT
# 4933  BS-2016-PKI-GSP-08  NaT
# 4934  BS-2016-PKI-GSP-08  NaT
# 4935   EX-2017-PKI-AD-01  NaT
# 4938      PE-GSP-2016003  NaT
# 4939       PE-AD-2017020  NaT
# 4940      PE-PP9-2018001  NaT
# 4941       LU-LX-2016003  NaT
# 4942      PE-GSP-2016003  NaT
# 4943       PE-AD-2017020  NaT
# 4944       PE-DX-2018008  NaT
# 4953     LAK-GSL-2011003  NaT
# 4954     LAK-GSL-2011003  NaT
# 4955     TMN-CDS-2011001  NaT
# 4956     LAK-GSL-2011003  NaT
# 4957     LAK-GSL-2011003  NaT
# 4958     LAK-GSL-2011003  NaT
# 4959     TMN-CDS-2011001  NaT
# 4990     LAK-GSL-2016011  NaT
# 4991     TMF-GCS-2015001  NaT
# 4992      PE-GSP-2017010  NaT
# 4993      PE-PP9-2017013  NaT
# 4994     TMF-GCS-2015001  NaT
# 4995       PE-AD-2010003  NaT
# 4996      PE-GSP-2017010  NaT
# 4997       PE-AD-2010003  NaT
# 4998     TMF-GCS-2015001  NaT
# 4999      PE-GSP-2017010  NaT
# 5000       PE-AD-2010003  NaT
# 5001      PE-GSP-2017010  NaT
# 5002     TMF-GCS-2015001  NaT
# 5003     TMF-GCS-2015001  NaT
# 5004     TMF-GCS-2015001  NaT
# 5005     LAK-GSL-2016011  NaT
# 5006      WTS-QM-2012003  NaT
# 5007      WTS-QM-2012003  NaT
# 5008      WTS-QM-2012003  NaT
# 5009     LAK-GSL-2016011  NaT
# 5010      PE-PP9-2017013  NaT
# 5011     TMF-GCS-2015001  NaT
# 5013     LAK-GSL-2015003  NaT
# 5016       PE-AD-2018004  NaT
# 5017      LAK-KM-2014002  NaT
# 5018       PE-AD-2018004  NaT
# 5026       PE-AD-2011007  NaT
# 5027     TMN-CDS-2012003  NaT
# 5028       PE-AD-2011007  NaT
# 5029     LAK-GSL-2018010  NaT
# 5030      LAK-KM-2010003  NaT
# 5031     LAK-GSL-2018007  NaT
# 5032      LAK-KM-2013002  NaT
# 5033       PE-AD-2011007  NaT
# 5037     LAK-GSL-2014004  NaT
# 5038      PE-GSP-2017002  NaT
# 5039       PE-AD-2014022  NaT
# 5040      PE-GSP-2017002  NaT
# 5041       PE-AD-2014022  NaT
# 5042     TMF-GCS-2017001  NaT
# 5043     TMF-GCS-2017001  NaT
# 5044     TMN-CDS-2018016  NaT
# 5045     LAK-GSL-2014004  NaT
# 5046       LU-LX-2017006  NaT
# 5047  SBA-CAP2FP-2014006  NaT
# 5048       PE-AD-2014022  NaT
# 5049     LAK-GSL-2014004  NaT
# 5050     TMF-GCS-2017001  NaT
# 5051  SBA-CAP2FP-2014006  NaT
# 5052      PE-PP9-2017001  NaT
# 5053       PE-AD-2014022  NaT
# 5069     LAK-GSL-2018011  NaT
# 5070     LAK-GSL-2018011  NaT
# 5071     LAK-GSL-2018011  NaT
# 5072     LAK-GSL-2018011  NaT
# 5073     LAK-GSL-2018011  NaT
# 5074   BS-20XX-PKI-VD-08  NaT
# 5079           TM-GSP-01  NaT
# 5082      PE-GSP-2017001  NaT
# 5083     LAK-GSL-2014011  NaT
# 5084      PE-GSP-2017001  NaT
# 5085      PE-GSP-2017001  NaT
# 5104      WTS-QM-2010003  NaT
# 5105    WTS-XTQD-2018001  NaT
# 5106      WTS-QM-2010003  NaT
# 5107       PE-AD-2017018  NaT
# 5108      PE-PP9-2018005  NaT
# 5109     LAK-GSL-2016003  NaT
# 5110     LAK-GSL-2009002  NaT
# 5111     LAK-GSL-2016003  NaT
# 5112     TMF-GCS-2014003  NaT
# 5113      PE-GSP-2016002  NaT
# 5114       LU-LX-2014001  NaT
# 5115    WTS-XTQD-2018001  NaT
# 5116     LAK-GSL-2016003  NaT
# 5117      PE-PP9-2014002  NaT
# 5118      PE-GSP-2016002  NaT
# 5119       LU-LX-2014001  NaT
# 5120       LU-LX-2014001  NaT
# 5121       LU-LX-2014001  NaT
# 5122      PE-PP9-2014002  NaT
# 5123       LU-LX-2014001  NaT
# 5124      PE-GSP-2016002  NaT
# 5128     LAK-GSL-2016014  NaT
# 5158      PE-GSP-2017011  NaT
# 5159     LAK-GSL-2014003  NaT
# 5160      PE-PP9-2014009  NaT
# 5161       PE-AD-2017004  NaT
# 5162       PE-AD-2009003  NaT
# 5163      PE-GSP-2017011  NaT
# 5164      PE-GSP-2017011  NaT
# 5165       PE-AD-2017004  NaT
# 5166       PE-AD-2017004  NaT
# 5167       PE-AD-2017004  NaT
# 5168       PE-AD-2009003  NaT
# 5169       PE-AD-2017004  NaT
# 5170     WTS-TQD-2014003  NaT
# 5171      PE-GSP-2017011  NaT
# 5172      PE-GSP-2017011  NaT
# 5173       PE-AD-2017004  NaT
# 5174     LAK-GSL-2014003  NaT
# 5175     LAK-GSL-2014003  NaT
# 5176      PE-GSP-2017011  NaT
# 5177      PE-PP9-2014009  NaT
# 5178       PE-AD-2017004  NaT
# 5179       PE-AD-2009003  NaT
# 5192     LAK-GSL-2010004  NaT
# 5193       PE-AD-2009004  NaT
# 5194     LAK-GSL-2010004  NaT
# 5195     LAK-GSL-2010004  NaT
# 5196       LU-LX-2014002  NaT
# 5197     LAK-GSL-2010004  NaT
# 5198     TMF-GCS-2014004  NaT
# 5199     TMF-GCS-2014004  NaT
# 5200     TMF-GCS-2014004  NaT
# 5204   BS-20XX-PKI-WS-11  NaT
# 5207       PE-AD-2018001  NaT
# 5208       PE-VT-2004005  NaT
# 5210       PE-DX-2016002  NaT
# 5215       PE-AD-2014019  NaT
# 5216    WTS-TQD-20180001  NaT
# 5217    WTS-TQD-20180001  NaT
# 5218   BS-20XX-PKI-WS-21  NaT
# 5231       PE-AD-2009005  NaT
# 5232      LAK-KM-2010006  NaT
# 5233       PE-AD-2009005  NaT
# 5234      LAK-KM-2010006  NaT
# 5235      LAK-KM-2015002  NaT
# 5236     TMN-CDS-2014005  NaT
# 5237       PE-AD-2009005  NaT
# 5238     TMN-CDS-2014005  NaT
# 5239      LAK-KM-2010006  NaT
# 5243      PE-PP9-2016014  NaT
# 5244      PE-GSP-2016009  NaT
# 5245      PE-PP9-2016014  NaT
# 5246      PE-VT-20060001  NaT
# 5248       PE-AD-2013015  NaT
# 5249       PE-AD-2013015  NaT
# 5251       PE-AD-2015011  NaT
# 5252     LAK-GSL-2018011  NaT
# 5253       PE-AD-2015011  NaT
# 5254                  其他  NaT
# 5255                  其他  NaT
# 5257       PE-AD-2018011  NaT
# 5261       PE-AD-2017007  NaT
# 5267       PE-AD-2013019  NaT
# 5268     TMN-CDS-2018010  NaT
# 5269     LAK-GSL-2017001  NaT
# 5270     LAK-GSL-2017001  NaT
# 5273       PE-VT-2003003  NaT
# 5274       PE-VT-2003003  NaT
# 5295     TMF-GCS-2016001  NaT
# 5296       PE-AD-2015015  NaT
# 5297       PE-AD-2015015  NaT
# 5298      PE-PP9-2016016  NaT
# 5299       PE-VT-2010003  NaT
# 5300     LAK-GSL-2012008  NaT
# 5301     TMN-CDS-2015009  NaT
# 5302      PE-PP9-2016016  NaT
# 5303      PE-PP9-2016016  NaT
# 5304       PE-AD-2015015  NaT
# 5306     WTS-TQD-2016007  NaT
# 5307     TMN-CDS-2016005  NaT
# 5308     WTS-TQD-2016007  NaT
# 5334      PE-GSP-2016012  NaT
# 5335      PE-GSP-2016006  NaT
# 5336       PE-AD-2013013  NaT
# 5337      PE-GSP-2016012  NaT
# 5338      PE-GSP-2016006  NaT
# 5339       PE-AD-2013013  NaT
# 5340     LAK-GSL-2016010  NaT
# 5341      PE-GSP-2016012  NaT
# 5342      PE-GSP-2016006  NaT
# 5343     LAK-GSL-2016010  NaT
# 5344      PE-PP9-2016007  NaT
# 5345     TMF-GCS-2016006  NaT
# 5346      PE-PP9-2014004  NaT
# 5350       PE-VT-2008008  NaT
# 5351       PE-VT-2008008  NaT
# 5357       PE-AD-2017006  NaT
# 5358       PE-AD-2017006  NaT
# 5359   BS-20XX-PKI-WS-20  NaT
# 5369    WTS-XTQD-2018004  NaT
# 5378      PE-GSP-2016005  NaT
# 5379      PE-PP9-2016005  NaT
# 5380       PE-VT-2007005  NaT
# 5381       PE-AD-2012006  NaT
# 5382       PE-AD-2012006  NaT
# 5383  SBA-CAP2FP-2013001  NaT
# 5384       PE-AD-2012006  NaT
# 5385      PE-PP9-2016005  NaT
# 5386      PE-GSP-2016005  NaT
# 5387      PE-GSP-2016005  NaT
# 5388      PE-GSP-2016005  NaT
# 5389       PE-VT-2007007  NaT
# 5404       PE-AD-2012007  NaT
# 5405       PE-AD-2012007  NaT
# 5406       PE-AD-2012007  NaT
# 5407     TMF-GCS-2014002  NaT
# 5408     LAK-GSL-2013002  NaT
# 5409       PE-AD-2012007  NaT
# 5410     LAK-GSL-2013002  NaT
# 5411       PE-AD-2012007  NaT
# 5412      LAK-KM-2017004  NaT
# 5413       PE-DX-2017002  NaT
# 5415       PE-AD-2013014  NaT
# 5436     TMF-GCS-2016004  NaT
# 5437       PE-AD-2013001  NaT
# 5438       PE-AD-2013001  NaT
# 5439      PE-PP9-2015004  NaT
# 5440      PE-PP9-2017010  NaT
# 5441     LAK-GSL-2011004  NaT
# 5442       PE-AD-2013001  NaT
# 5443      PE-GSP-2015003  NaT
# 5444      PE-GSP-2015003  NaT
# 5445      PE-GSP-2015003  NaT
# 5446     TMF-GCS-2016004  NaT
# 5447     TMF-GCS-2016004  NaT
# 5448       PE-AD-2013001  NaT
# 5449     LAK-GSL-2011004  NaT
# 5456       PE-AD-2017019  NaT
# 5457       PE-AD-2017019  NaT
# 5458       PE-AD-2017019  NaT
# 5459      LAK-KM-2018002  NaT
# 5460       PE-AD-2017019  NaT
# 5474   BS-2007-PKI-SK-02  NaT
# 5476     WTS-TQD-2016002  NaT
# 5477       PE-AD-2012009  NaT
# 5478       PE-AD-2012009  NaT
# 5479       PE-AD-2012009  NaT
# 5489       PE-AD-2013011  NaT
# 5490     LAK-GSL-2013005  NaT
# 5491     TMF-GCS-2017009  NaT
# 5492       PE-AD-2013011  NaT
# 5493     LAK-GSL-2013005  NaT
# 5494     TMF-GCS-2017009  NaT
# 5498     TMF-GCS-2015004  NaT
# 5499     LAK-GSL-2013006  NaT
# 5506     LAK-GSL-2016006  NaT
# 5566     WTS-TQD-2017014  NaT
# 5567      WTS-QM-2013001  NaT
# 5568       PE-AD-2017011  NaT
# 5569       PE-AD-2011008  NaT
# 5570      WTS-QM-2013001  NaT
# 5571     WTS-TQD-2017014  NaT
# 5572       PE-AD-2017011  NaT
# 5573      WTS-QM-2013001  NaT
# 5574       PE-AD-2014001  NaT
# 5575     TMF-GCS-2017008  NaT
# 5576     LAK-GSL-2012005  NaT
# 5577     TMN-CDS-2012001  NaT
# 5578       PE-AD-2011008  NaT
# 5579     TMF-GCS-2017008  NaT
# 5580     WTS-TQD-2017014  NaT
# 5581      WTS-QM-2013001  NaT
# 5582     LAK-GSL-2017004  NaT
# ...                  ...  ...
# 5696       PE-AD-2014003  NaT
# 5697       PE-AD-2013007  NaT
# 5698       PE-AD-2014003  NaT
# 5699     WTS-TQD-2016003  NaT
# 5700      WTS-QM-2012001  NaT
# 5701     LAK-GSL-2012004  NaT
# 5702     TMF-GCS-2013003  NaT
# 5703       PE-AD-2011011  NaT
# 5709       PE-DX-2013001  NaT
# 5710       PE-DX-2013001  NaT
# 5711       PE-DX-2013001  NaT
# 5712       PE-DX-2013001  NaT
# 5713       PE-DX-2013001  NaT
# 5720     TMN-CDS-2015001  NaT
# 5721     TMN-CDS-2015001  NaT
# 5753       PE-AD-2011004  NaT
# 5754  SBA-CAP2FP-2014002  NaT
# 5755      PE-GSP-2016001  NaT
# 5756      PE-GSP-2016001  NaT
# 5757       PE-VT-2001010  NaT
# 5758      PE-PP9-2013001  NaT
# 5759       PE-AD-2011004  NaT
# 5760  SBA-CAP2FP-2014002  NaT
# 5761     LAK-GSL-2017007  NaT
# 5762      PE-GSP-2016001  NaT
# 5763       PE-AD-2011004  NaT
# 5764      PE-GSP-2016001  NaT
# 5774     WTS-TQD-2015017  NaT
# 5775       PE-AD-2011010  NaT
# 5776       PE-AD-2011010  NaT
# 5777       PE-AD-2011010  NaT
# 5778       PE-AD-2011010  NaT
# 5779     WTS-TQD-2015017  NaT
# 5780     LAK-GSL-2018001  NaT
# 5781       PE-AD-2011010  NaT
# 5782       PE-DX-2018009  NaT
# 5786       PE-AD-2015010  NaT
# 5793       PE-AD-2008004  NaT
# 5794       PE-AD-2008004  NaT
# 5795       PE-AD-2008004  NaT
# 5796       PE-AD-2008004  NaT
# 5802      WTS-QM-2016002  NaT
# 5803      WTS-QM-2016002  NaT
# 5804      WTS-QM-2016002  NaT
# 5805      PE-PP9-2015005  NaT
# 5806       PE-VT-2010001  NaT
# 5807      PE-PP9-2015005  NaT
# 5808     LAK-GSL-20XX001  NaT
# 5809     LAK-GSL-20XX001  NaT
# 5810     TMN-CDS-2013003  NaT
# 5811       PE-AD-2015005  NaT
# 5823  SBA-CAP2FP-2016006  NaT
# 5824       PE-AD-2017003  NaT
# 5825       PE-VT-2003002  NaT
# 5826      LAK-MB-2009001  NaT
# 5827     TMF-GCS-2017011  NaT
# 5828       LU-LX-2017007  NaT
# 5829     TMN-CDS-2016014  NaT
# 5830     TMN-CDS-2008001  NaT
# 5831      PE-GSP-2018006  NaT
# 5832      PE-PP9-2018004  NaT
# 5833     TMN-CDS-2018018  NaT
# 5834       PE-VT-2003002  NaT
# 5835       PE-AD-2017003  NaT
# 5847     LAK-GSL-2015009  NaT
# 5848     LAK-GSL-2015009  NaT
# 5860     TMN-CDS-2016015  NaT
# 5861     TMN-CDS-2016015  NaT
# 5869     TMF-GCS-2014001  NaT
# 5870     LAK-GSL-2014005  NaT
# 5871     TMF-GCS-2014001  NaT
# 5872     TMN-CDS-2016025  NaT
# 5876     WTS-TQD-2015007  NaT
# 5877     WTS-TQD-2015007  NaT
# 5881     TMF-GCS-2013002  NaT
# 5882     TMF-GCS-2013002  NaT
# 5883     TMF-GCS-2013002  NaT
# 5886     TMF-GCS-2013001  NaT
# 5887     TMF-GCS-2013001  NaT
# 5888     TMF-GCS-2013001  NaT
# 5893  SBA-CAP2FP-2016012  NaT
# 5894  SBA-CAP2FP-2016012  NaT
# 5922      PE-PP9-2016009  NaT
# 5923     TMN-CDS-2016018  NaT
# 5924      PE-GSP-2016007  NaT
# 5925       PE-AD-2015006  NaT
# 5926       PE-AD-2015006  NaT
# 5927       PE-AD-2015006  NaT
# 5928  SBA-CAP2FP-2014003  NaT
# 5929      PE-PP9-2016009  NaT
# 5930       PE-AD-2015006  NaT
# 5931      PE-PP9-2016009  NaT
# 5932  SBA-CAP2FP-2014003  NaT
# 5933      PE-GSP-2016007  NaT
# 5934     TMN-CDS-2016018  NaT
# 5935      LAK-KM-2016004  NaT
# 5940     LAK-GSL-2013003  NaT
# 5941       PE-AD-2011001  NaT
# 5942      LAK-KM-2009006  NaT
# 5943     LAK-GSL-2013003  NaT
# 5944     LAK-GSL-2013003  NaT
# 5945     LAK-GSL-2013003  NaT
# 5946     LAK-GSL-2013003  NaT
# 5948    WTS-TQ S-2013001  NaT
# 5949    WTS-TQ S-2013001  NaT
# 5953       PE-AD-2017008  NaT
# 5958     LAK-GSL-2016005  NaT
# 5959       PE-DX-2017001  NaT
# 5960     LAK-GSL-2016005  NaT
# 5961     LAK-GSL-2016005  NaT
# 5964       PE-AD-2014008  NaT
# 5965       PE-AD-2014008  NaT
# 5966       PE-AD-2014008  NaT
# 5970     LAK-GSL-2016013  NaT
# 5971     LAK-GSL-2016013  NaT
# 5972     LAK-GSL-2016013  NaT
# 5973     LAK-GSL-2016013  NaT
# 5974     LAK-GSL-2016013  NaT
# 5975       PE-DX-2018003  NaT
# 5980       PE-AD-2013008  NaT
# 5981       PE-DX-2018007  NaT
# 5982       PE-DX-2018007  NaT
# 5983     LAK-GSL-2014020  NaT
# 5984     LAK-GSL-2014020  NaT
# 5985     LAK-GSL-2014020  NaT
# 6030       PE-AD-2009002  NaT
# 6031       PE-DX-2016001  NaT
# 6032     TMF-GCS-2015003  NaT
# 6033     TMF-GCS-2015003  NaT
# 6034     WTS-TQD-2013001  NaT
# 6035     WTS-TQD-2016013  NaT
# 6036      PE-PP9-2014003  NaT
# 6037      PE-GSP-2017008  NaT
# 6038       PE-DX-2016001  NaT
# 6039       PE-AD-2009002  NaT
# 6040       PE-DX-2016001  NaT
# 6041       PE-AD-2009002  NaT
# 6042       PE-AD-2016008  NaT
# 6043       PE-DX-2016001  NaT
# 6044      PE-PP9-2014003  NaT
# 6045      PE-PP9-2016017  NaT
# 6046      PE-GSP-2017008  NaT
# 6047      PE-GSP-2017008  NaT
# 6048      PE-GSP-2017008  NaT
# 6049       PE-AD-2016008  NaT
# 6050     TMF-GCS-2015003  NaT
# 6051       PE-AD-2009002  NaT
# 6052     TMF-GCS-2015003  NaT
# 6053       PE-VT-2011003  NaT
# 6056       PE-AD-2018005  NaT
# 6058       PE-DX-2018004  NaT
# 6059       PE-AD-2018002  NaT
# 6060       PE-AD-2018002  NaT
# 6065       PE-AD-2013006  NaT
# 6068     WTS-TQD-2012002  NaT
# 6069     WTS-TQD-2012002  NaT
# 6071       PE-DX-2108002  NaT
# 6072     LAK-GSL-2013007  NaT
# 6073       PE-DX-2108002  NaT
# 6074       PE-DX-2108002  NaT
# 6076       PE-VT-2004002  NaT
# 6080     LAK-GSL-2017010  NaT
# 6081       PE-AD-2018014  NaT
# 6082     LAK-GSL-2017010  NaT
# 6083     TMF-GCS-2018011  NaT
# 6088       PE-AD-2016010  NaT
# 6089     LAK-GSL-2014009  NaT
# 6090     WTS-TQD-2014007  NaT
# 6091       PE-AD-2016010  NaT
# 6092     LAK-GSL-2014009  NaT
# 6107      PE-GSP-2017013  NaT
# 6108     LAK-GSL-2016009  NaT
# 6109      PE-PP9-2017005  NaT
# 6110      PE-GSP-2017013  NaT
# 6111    WTS-XTQD-2017020  NaT
# 6112    WTS-XTQD-2017020  NaT
# 6113      PE-GSP-2017013  NaT
# 6114    WTS-XTQD-2017020  NaT
# 6115      PE-GSP-2017013  NaT
# 6117     LAK-GSL-2017002  NaT
# 6118       PE-VT-2000004  NaT
# 6120       PE-AD-2017017  NaT
# 6123     LAK-GSL-2016018  NaT
# 6124       PE-AD-2014020  NaT
# 6125     LAK-GSL-2016018  NaT
# 6126     LAK-GSL-2016018  NaT
# 6127     TMN-CDS-2018015  NaT
# 6153     TMF-GCS-2018002  NaT
# 6154     TMF-GCS-2018002  NaT
# 6155       PE-AD-2015007  NaT
# 6156     LAK-GSL-2014006  NaT
# 6157       PE-AD-2015007  NaT
# 6158       PE-AD-2016005  NaT
# 6159     LAK-GSL-2014006  NaT
# 6160     TMF-GCS-2018002  NaT
# 6161   LAK-KM-2018002（E）  NaT
# 6162   LAK-KM-2018002（E）  NaT
# 6163     LAK-GSL-2018007  NaT
# 6164     TRN-CDS-2018003  NaT
# 6165       PE-DX-2018006  NaT
# 6166       PE-DX-2018006  NaT
# 6167     LAK-GSL-2018006  NaT
# 6168     TMN-CDS-2018008  NaT
# 6175       PE-AD-2017014  NaT
# 6176       LU-LX-2018001  NaT
# 6177       PE-VT-2003006  NaT
# 6178       PE-VT-2003006  NaT
# 6179       PE-VT-2007009  NaT
# 6181       PE-AD-2018006  NaT
# 6182       PE-AD-2018006  NaT
# 6188     WTS-TQD-2015015  NaT
# 6189     WTS-TQD-2015015  NaT
# 6190       PE-AD-2015001  NaT
# 6191       PE-VT-2009008  NaT
# 6192       PE-VT-2009008  NaT
# 6193     WTS-TQD-2015015  NaT
# 6194       PE-AD-2015001  NaT
# 6201      WTS-QM-2016003  NaT
# 6202      WTS-QM-2016003  NaT
# 6203      WTS-QM-2016003  NaT
# 6204      LAK-KM-2018003  NaT
# 6205      LAK-KM-2018003  NaT
# 6206  SBA-CAP2FP-2014007  NaT
# 6207       PE-AD-2018008  NaT
# 6208      LAK-KM-2018003  NaT
# 6209      WTS-QM-2016003  NaT
# 6210      WTS-QM-2016003  NaT
# 6215   BS-20XX-PKI-SK-08  NaT
# 6216   BS-20XX-PKI-WS-05  NaT
# 6222       PE-AD-2017015  NaT
# 6229      PE-GSP-2017009  NaT
# 6230       PE-AD-2017012  NaT
# 6241     LAK-GSL-2017008  NaT
# 6242       PE-AD-2017009  NaT
# 6243     LAK-GSL-2017008  NaT
# 6246       PE-AD-2015002  NaT
# 6247      PE-PP9-2016008  NaT
# 6248       PE-AD-2015002  NaT
# 6249       PE-DX-2017003  NaT
# 6263       PE-DX-2017004  NaT
# 6264      PE-PP9-2017009  NaT
# 6265      PE-GSP-2018002  NaT
# 6266      PE-PP9-2017009  NaT
# 6267      PE-PP9-2017009  NaT
# 6268      PE-PP9-2017009  NaT
# 6269      PE-PP9-2017009  NaT
# 6270      PE-GSP-2018002  NaT
# 6271      PE-GSP-2018002  NaT
# 6272      PE-GSP-2018002  NaT
# 6273      PE-PP9-2017009  NaT
# 6313      PE-PP9-2015003  NaT
# 6314       LU-LX-2017004  NaT
# 6315      PE-PP9-2015002  NaT
# 6316      PE-GSP-2015002  NaT
# 6317       PE-VT-2001005  NaT
# 6318     TMF-GCS-2017010  NaT
# 6319      PE-PP9-2015003  NaT
# 6320       PE-AD-2015009  NaT
# 6321     LAK-GSL-2011001  NaT
# 6322      PE-GSP-2015002  NaT
# 6323     WTS-TQD-2015010  NaT
# 6324     WTS-TQD-2016022  NaT
# 6325     WTS-TQD-2015010  NaT
# 6326      PE-GSP-2015002  NaT
# 6327     WTS-TQD-2015010  NaT
# 6328     WTS-TQD-2016022  NaT
# 6329     WTS-TQD-2016022  NaT
# 6330     WTS-TQD-2016022  NaT
# 6331     WTS-TQD-2015010  NaT
# 6332      PE-GSP-2015002  NaT
# 6333      PE-PP9-2015003  NaT
# 6334       PE-AD-2015009  NaT
# 6346     LAK-GSL-2015006  NaT
# 6347       PE-DX-2017006  NaT
# 6348     LAK-GSL-2015006  NaT
# 6349     LAK-GSL-2015006  NaT
# 6350     LAK-GSL-2015006  NaT
# 6351     LAK-GSL-2015006  NaT
# 6352     LAK-GSL-2015006  NaT
# 6353       PE-DX-2017006  NaT
# 6354       PE-DX-2018009  NaT
# 6355     LAK-GSL-2018010  NaT
# 6356       PE-DX-2018005  NaT
# 6357       PE-DX-2018005  NaT
# 6372   BS-20XX-PKI-VD-03  NaT
# 6377      LAK-KM-2012001  NaT
# 6378     WTS-TQD-2012001  NaT
# 6379       PE-AD-2011005  NaT
# 6380      PE-GSP-2017015  NaT
# 6381      PE-PP9-2014011  NaT
# 6382      PE-GSP-2017015  NaT
# 6383       PE-AD-2011005  NaT
# 6389       PE-VT-2004001  NaT
# 6390       PE-AD-2014006  NaT
# 6404     LAK-GSL-2016016  NaT
# 6405      PE-PP9-2017008  NaT
# 6406       PE-AD-2016001  NaT
# 6407   EX-20XX-PKI-AD-01  NaT
# 6410       PE-AD-2012003  NaT
# 6411       PE-VT-2016004  NaT
# 6412      PE-PP9-2016013  NaT
# 6413       PE-AD-2012003  NaT
# 6414       PE-AD-2012003  NaT
# 6419       PE-AD-2014021  NaT
# 6420       PE-AD-2014021  NaT
# 6421       PE-AD-2014021  NaT
# 6427       PE-AD-2014009  NaT
# 6428       PE-AD-2014009  NaT
# 6429       PE-AD-2014009  NaT
# 6430       PE-AD-2014009  NaT
# 6443       PE-AD-2015003  NaT
# 6444       PE-AD-2015003  NaT
# 6445       PE-AD-2015003  NaT
# 6446      PE-PP9-2016002  NaT
# 6447  SBA-CAP2FP-2015001  NaT
# 6448      PE-PP9-2016002  NaT
# 6449     LAK-GSL-2016012  NaT
# 6450       PE-AD-2015003  NaT
# 6451      PE-PP9-2016002  NaT
# 6452     LAK-GSL-2016012  NaT
# 6453     TMN-CDS-2018013  NaT
# 6456       PE-AD-2015013  NaT
# 6480  SBA-CAP2FP-2014004  NaT
# 6481      PE-GSP-2016010  NaT
# 6482  SBA-CAP2FP-2014004  NaT
# 6483       PE-AD-2014010  NaT
# 6484  SBA-CAP2FP-2014004  NaT
# 6485      PE-GSP-2016010  NaT
# 6486      PE-GSP-2016010  NaT
# 6487  SBA-CAP2FP-2014004  NaT
# 6488      PE-PP9-2016012  NaT
# 6489      PE-PP9-2016012  NaT
# 6490      PE-GSP-2016010  NaT
# 6491      PE-PP9-2016012  NaT
# 6492  SBA-CAP2FP-2014004  NaT
# 6525  SBA-CAP2FP-2014005  NaT
# 6526     WTS-TQD-2017019  NaT
# 6527     LAK-GSL-2016002  NaT
# 6528       PE-AD-2014007  NaT
# 6529       PE-AD-2014007  NaT
# 6530      PE-GSP-2017014  NaT
# 6531      PE-PP9-2017006  NaT
# 6532       PE-AD-2014007  NaT
# 6533       PE-AD-2014007  NaT
# 6534       PE-VT-2003009  NaT
# 6535     TMN-CDS-2016001  NaT
# 6536     LAK-GSL-2016002  NaT
# 6537       PE-AD-2014007  NaT
# 6538       PE-AD-2014007  NaT
# 6539      PE-GSP-2017014  NaT
# 6540     LAK-GSL-2016002  NaT
# 6541      PE-GSP-2017014  NaT
# 6542      PE-PP9-2017006  NaT
# 6543  SBA-CAP2FP-2014005  NaT
# 6551       PE-AD-2017001  NaT
# 6559      PE-GSP-2017007  NaT
# 6560      PE-PP9-2016003  NaT
# 6561      PE-GSP-2017007  NaT
# 6562      PE-PP9-2016003  NaT
# 6563      PE-GSP-2017007  NaT
# 6564      PE-PP9-2016003  NaT
# 6601      PE-GSP-2016008  NaT
# 6602     WTS-TQD-2014005  NaT
# 6603      PE-PP9-2014010  NaT
# 6604       PE-AD-2012010  NaT
# 6605       PE-AD-2012010  NaT
# 6606     WTS-TQD-2014005  NaT
# 6607      PE-GSP-2016008  NaT
# 6608       PE-AD-2012010  NaT
# 6609     WTS-TQD-2014005  NaT
# 6610      PE-GSP-2016008  NaT
# 6611     TMN-CDS-2016008  NaT
# 6612     LAK-GSL-2015002  NaT
# 6613       PE-AD-2012010  NaT
# 6614     WTS-TQD-2014005  NaT
# 6615     TMF-GCS-2017003  NaT
# 6616      PE-PP9-2014010  NaT
# 6617     WTS-TQD-2014005  NaT
# 6618     TMN-CDS-2016008  NaT
# 6619       PE-AD-2012010  NaT
# 6620       PE-AD-2012010  NaT
# 6625   BS-20XX-PKI-SK-04  NaT
# 6627   BS-20XX-PKI-WS-03  NaT
# 6628       PE-VT-2016001  NaT
# 6629       PE-VT-2016001  NaT
# 6631    LAK-GSL-20170001  NaT
# 6632    TMF-GCS-20170001  NaT
# 6633     WTS-TQD-2015005  NaT
# 6634     WTS-TQD-2015005  NaT
# 6646          BY-WTS-002  NaT
# 6647          BY-WTS-001  NaT
# 6648          BY-WTS-001  NaT
# 6717      PE-GSP-2017004  NaT
# 6718     TMF-GCS-2016002  NaT
# 6719     WTS-TQD-2017015  NaT
# 6720     TMF-GCS-2016002  NaT
# 6721     WTS-TQD-2013004  NaT
# 6722     WTS-TQD-2016016  NaT
# 6723       PE-AD-2014004  NaT
# 6724       PE-AD-2013016  NaT
# 6725       PE-AD-2014013  NaT
# 6726      PE-GSP-2017004  NaT
# 6727      PE-GSP-2017005  NaT
# 6728      PE-PP9-2017007  NaT
# 6729     WTS-TQD-2017015  NaT
# 6730      PE-GSP-2017004  NaT
# 6731     WTS-TQD-2017015  NaT
# 6732     WTS-TQD-2016016  NaT
# 6733     WTS-TQD-2017001  NaT
# 6734      PE-PP9-2014005  NaT
# 6735      PE-PP9-2017007  NaT
# 6736     WTS-TQD-2016016  NaT
# 6737      PE-GSP-2017005  NaT
# 6738      PE-GSP-2017004  NaT
# 6739      PE-PP9-2014005  NaT
# 6740       PE-AD-2014013  NaT
# 6741       PE-AD-2014004  NaT
# 6742       PE-AD-2013016  NaT
# 6743      PE-PP9-2014007  NaT
# 6744      PE-PP9-2014006  NaT
# 6745      PE-GSP-2017005  NaT
# 6746      PE-PP9-2014006  NaT
# 6747       PE-AD-2014004  NaT
# 6748      PE-GSP-2017005  NaT
# 6749       PE-AD-2013016  NaT
# 6750      PE-GSP-2017004  NaT
# 6751       PE-AD-2013016  NaT
# 6752     TMF-GCS-2016002  NaT
# 6753      PE-GSP-2018005  NaT
# 6754       PE-AD-2013016  NaT
# 6755       PE-AD-2014013  NaT
# 6756      PE-GSP-2017004  NaT
# 6757      PE-GSP-2017004  NaT
# 6758      PE-PP9-2017007  NaT
# 6759       PE-AD-2014004  NaT
# 6760      PE-PP9-2014005  NaT
# 6761      PE-PP9-2014006  NaT
# 6762      PE-PP9-2014007  NaT
# 6763      PE-PP9-2013002  NaT
# 6798     LAK-GSL-2011002  NaT
# 6799     TMF-GCS-2010001  NaT
# 6800     LAK-GSL-2011002  NaT
# 6801     LAK-GSL-2011002  NaT
# 6802     LAK-GSL-2011002  NaT
# 6803     LAK-GSL-2011002  NaT
# 6804     TMN-CDS-2011003  NaT
# 6805     TMN-CDS-2014002  NaT
# 6806     TMF-GCS-2010001  NaT
# 6807       PE-AD-2017005  NaT
# 6808     LAK-GSL-2011002  NaT
# 6809     TMF-GCS-2010001  NaT
# 6810       PE-AD-2017005  NaT
# 6811     TMF-GCS-2010001  NaT
# 6817     LAK-GSL-2017005  NaT
# 6818     LAK-GSL-2017005  NaT
# 6819     TMN-CDS-2017003  NaT
# 6820     LAK-GSL-2017005  NaT
# 6821     LAK-GSL-2017005  NaT
# 6822     LAK-GSL-2017005  NaT
# 6834     LAK-GSL-2017009  NaT
# 6835     TMN-CDS-2018009  NaT
# 6836     TMN-CDS-2018009  NaT
# 6837     TMN-CDS-2018009  NaT
# 6838       PE-AD-2010009  NaT
# 6839       PE-AD-2016007  NaT
# 6840     LAK-GSL-2017009  NaT
# 6841     LAK-GSL-2017009  NaT
# 6842       PE-AD-2013005  NaT
# 6843       PE-AD-2013005  NaT
# 6851     LAK-GSL-2015005  NaT
# 6852     LAK-GSL-2015005  NaT
# 6853       PE-VT-2014003  NaT
# 6854       PE-AD-2017016  NaT
# 6855     LAK-GSL-2015005  NaT
# 6856       PE-AD-2017016  NaT
# 6859     TMF-GCS-2016009  NaT
# 6860     TMF-GCS-2016009  NaT
# 6861     TMF-GCS-2016009  NaT
# 6862     TMN-CDS-2018017  NaT
# 6873       PE-AD-2012008  NaT
# 6885       PE-AD-2014011  NaT
# 6886       PE-AD-2014011  NaT
# 6887       PE-VT-2009001  NaT
# 6888    AN-NS550-2018001  NaT
# 6889       PE-AD-2014011  NaT
# 6890  SBA-CAP2FP-2014001  NaT
# 6891       PE-AD-2014011  NaT
# 6904      PE-GSP-2015001  NaT
# 6905      PE-GSP-2015001  NaT
# 6906       PE-AD-2010002  NaT
# 6907       PE-AD-2010002  NaT
# 6908      PE-PP9-2014008  NaT
# 6909      PE-PP9-2014008  NaT
# 6910      PE-GSP-2015001  NaT
# 6911     TMF-GCS-2015002  NaT
# 6912       PE-AD-2010002  NaT
# 6913      PE-GSP-2015001  NaT
# 6914       PE-AD-2014014  NaT
# 6915       PE-AD-2010002  NaT
# 6916      PE-GSP-2015001  NaT
#
# [1047 rows x 2 columns]

# %%
a = 'BS-20XX-PKI-WR-03'

a[a.index('20'):a.index('20')+4]
# Out:
# '20XX'

# %%
def find_year(x):
    if '20' in x:
        output = x[x.index('20'):x.index('20')+4]
    elif '19' in x:
        output = x[x.index('19'):x.index('19')+4]
    else:
        output = 'unknown'
    return output

data['装机年份'] = data['设备编号'].apply(find_year)

# %%
data['装机年份'].value_counts()
# Out:
# 2016       1377
# 2014       1188
# 2017       1022
# 2015        799
# 2013        643
# 2012        439
# 2011        367
# 2010        253
# 2018        183
# 2009        152
# 2008        103
# 2007         79
# 2003         69
# 20XX         68
# 2006         38
# 2001         38
# 2005         30
# 2004         19
# 2002         18
# unknown      13
# 2000         12
# 1999          6
# 2019          1
# Name: 装机年份, dtype: int64

# %% [markdown]
# 提取装机年份后可以看到，最常被维护和维修的反而是2016年的仪器，很多较早的仪器维修的反而更少，有可能是2016的总台数多，也有可能是较早的仪器已经被淘汰了

# %%
data.loc[data['装机年份'] == 'unknown',:]
# Out:
#                          服务单号              客户名称  客户类型 紧急程度     问题发现日期 分配工程师  \
# 2651  BS-SHFW-维修部201803294742          常德市妇幼保健院   VIP   重要 2018-03-23   徐琪枫
# 2669  BS-SHFW-维修部201803264698          淮安市妇幼保健院   VIP   正常 2018-03-26    宋挺
# 4614  BS-SHFW-维修部201803294742          常德市妇幼保健院   VIP   重要 2018-03-23   徐琪枫
# 5079  BS-SHFW-维修部201803264698          淮安市妇幼保健院   VIP   正常 2018-03-26    宋挺
# 5254  BS-SHFW-维修部201804114874  徕卡显微系统（上海）贸易有限公司   NaN   未知 2018-04-09    宋挺
# 5255  BS-SHFW-维修部201804124903  徕卡显微系统（上海）贸易有限公司   NaN   正常 2018-04-12   王强2
# 5603                        补          宁德市妇幼保健所   VIP   正常 2018-03-17   傅菲菲
# 6071            ZJBS181029023           泰安市中心医院  一般客户  无要求 2018-10-26   王新震
# 6073            ZJBS181121013           泰安市中心医院  一般客户   未知 2018-11-21   郑耀庭
# 6074            ZJBS181128005           泰安市中心医院  一般客户   未知 2018-11-28   戴明路
# 6646            ZJBS181110002    浙江博圣生物技术股份有限公司   NaN  无要求 2018-11-06    车鑫
# 6647            ZJBS181130004    浙江博圣生物技术股份有限公司   NaN  无要求 2018-11-26   傅菲菲
# 6648            ZJBS181201001    浙江博圣生物技术股份有限公司   NaN  无要求 2018-11-26    车鑫
#
#                设备编号            设备型号  服务工时(小时)  服务间隔天数     上次维修时间       装机日期  \
# 2651      TM-GSL-01         GSL-120      18.0     4.0        NaT        NaT
# 2669      TM-GSP-01       2021-0010       3.5     1.0        NaT        NaT
# 4614      TM-GSL-01  GSL-120/GSL-10       2.0     4.0 2018-03-23        NaT
# 5079      TM-GSP-01       2021-0010       3.5     1.0 2018-03-26        NaT
# 5254             其他  GSL-120/GSL-10       4.0     1.0        NaT        NaT
# 5255             其他  GSL-120/GSL-10       8.0     0.0 2018-04-09        NaT
# 5603            TQD             TQD      12.0     2.0 2016-07-26 2016-07-26
# 6071  PE-DX-2108002       6000-0010       2.5     4.0        NaT        NaT
# 6073  PE-DX-2108002       6000-0010       9.0     1.0 2018-10-26        NaT
# 6074  PE-DX-2108002       6000-0010      11.5     1.0 2018-11-21        NaT
# 6646     BY-WTS-002             TQS      12.0     0.0        NaT        NaT
# 6647     BY-WTS-001             TQS      24.0     1.0        NaT        NaT
# 6648     BY-WTS-001             TQS      18.0     1.0 2018-11-26        NaT
#
#      维修服务内容                                               问题汇总  \
# 2651    待确认  1235滤光片报错；1235年度维护；1420维护；P9维护；修改PAPPA靶值；确认120...
# 2669     其他        按计划进行仪器季度维护按计划进行季度testkit测试按计划进行季度testkit测试
# 4614    待确认  1235滤光片报错；1235年度维护；1420维护；P9维护；修改PAPPA靶值；确认120...
# 5079   维护保养                        按计划进行仪器季度维护按计划进行季度testkit测试
# 5254    待确认                                      Z轴电机异响，仪器无法对焦
# 5255    待确认                                  120无法开机，CTR6000损坏
# 5603     维修                       仪器响应低且瓜氨酸重现性不好仪器响应低&瓜氨酸重现性不好
# 6071     维修  仪器装机以来经常出现一两个样本报样本量太少，确定不是样本问题，大概率是架子问题，需要上门调整...
# 6073     维修         DX早上实验试剂枪报错无法取枪头和打枪头，检查过枪头等问题，重启仪器再做实验还是出现
# 6074     维修  客户运行定标曲线实验时发生liftmovererror，客户表示仪器内部有卡住的声音，应该是...
# 6646   维护保养                           基因小镇11楼存放的厦门妇幼TQD需要清洗四级杆
# 6647    待确认                                  仪器翻新潍坊质谱+厦门辅助设备翻新
# 6648   维护保养                                     设备投放江阴客户前，清洗维护
#
#                                                  解决方案汇总     装机年份
# 2651  1235滤光片报错；1、进入service，校准值为3025，按照手册内容将发射光滤光片的H...  unknown
# 2669  1.上周更换过风扇后目前仪器内部温度较为稳定，检查历史记录，温度均正常；2.运行洗板测试，洗...  unknown
# 4614  1、按照安装确认单内容查看场地2、桌子尺寸大小、UPS16A插头、温湿度等都正常3、唯一可能...  unknown
# 5079  1.上周更换过风扇后目前仪器内部温度较为稳定，检查历史记录，温度均正常；2.运行洗板测试，洗...  unknown
# 5254                                                     unknown
# 5255                                                     unknown
# 5603  发现离子腔和质谱之间有缝隙（应用工程师清洁离子腔后安装未到位），重装离子腔后响应恢复正常。1...  unknown
# 6071                      因为这个现象也是偶发，所以还有可能是老师放置的时候有偏差。  unknown
# 6073  现场查看，报错步进误差-183，怀疑为碰撞到物体进行test模块查看，未发现坐标偏差，进行t...  unknown
# 6074  1、针对问题1，检查发现Lift位置传感器相关的flag松动，进行紧固后，重新校准坐标，测试...  unknown
# 6646  维护内容：1、仪器清洗维护：四级杆、碰撞池、透镜、离子源清洗维护。2、毛细管更换3、仪器性能...  unknown
# 6647  1.使用龙岩装机运回的外包装，打包好孵育振荡器/超声波清洗器/氩气减压阀（这几个都是原厦门发...  unknown
# 6648  工作内容：1、清洗维护离子源和六级杆2、带教徐琪枫用peg调试仪器UPS故障学习：故障描述：...  unknown

# %% [markdown]
# 可以看到这部分装机年份unknown的样本，可能不是我们公司的仪器，所以是可以剔除的。

# %%
data = data.loc[data['装机年份'] != 'unknown',:].reset_index(drop = True)

# %% [markdown]
# ### 部分脏数据处理

# %%
instrument_uniq = data.drop_duplicates(subset = '设备编号', keep = 'last')
instrument_uniq.loc[instrument_uniq['设备型号'].isnull(),:]
# 发现共有两台仪器数据没有
data.loc[data['设备编号'] == 'BS-2016-WTS-TQS-01',:]
data.loc[data['设备编号'].apply(lambda x: 'WTS' in x), ['设备编号','设备型号']]
# 怀疑是陈凌云填错了，其实是TQD不是TQS
data.loc[data['设备编号'] == 'BS-2016-WTS-TQS-01','设备编号'] = 'BS-2016-WTS-TQD-01'
data.loc[data['设备编号'] == 'BS-2016-WTS-TQD-01','设备型号'] = 'TQD'
data.loc[data['设备编号'].apply(lambda x: 'NS' in x), ['设备编号','设备型号']]
data.loc[data['设备编号'] == 'BS-2017-NS550-01', '设备型号'] = 'Nextseq 550AR'

# %%
data.loc[data['设备型号'] == 'GCS3000Dx2', '设备型号'] = 'GCS3000DX2'
