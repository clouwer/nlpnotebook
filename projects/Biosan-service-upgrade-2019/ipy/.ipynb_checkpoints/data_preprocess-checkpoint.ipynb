# %% [markdown]
# ## 数据预处理
#
# 计划达到几个目的：
# 1. 提取有用字段
# 2. 数据去重
# 2. 插补缺失项
# 3. 将数据按仪器类型分开
# 4. 分类特征合并
# 4. 文本数据正则化
# 4. ETL后样本存入数据库

# %% [markdown]
# ### 数据读取

# %%
import pandas as pd
import numpy as np

import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn
warnings.simplefilter('ignore')

import sys
sys.path.extend(['../src/'])

from config import *

import matplotlib.pyplot as plt
import seaborn as sns

from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

% matplotlib inline

config = Config()

data = {}
for file in ['2015-2018维修数据_部分.xlsx', '2017维修数据.xlsx', '2018维修数据.xlsx']:
    data[file] = pd.read_excel('{}{}'.format(config.origin_data_filepath, file))

data_ = pd.concat(data).reset_index(drop = True)[data['2015-2018维修数据_部分.xlsx'].columns]

# %% [markdown]
# ### 提取有用字段、分类特征合并

# %% [markdown]
# #### 紧急程度字段
#
# 紧急程度这个字段为我们提供的信息是故障问题的定义
# 即什么样的部件故障是可以被评价为紧急故障
#
# 一种处理方式是紧急重要合并，其他全部当成正常。但是必存在很多偏差，
# 而且这列的缺失率较大。这部分信息尽量使用其他特征提取得出
# 最好的方式应该是，通过一部分样本定义哪些部件故障是紧急故障，然后其他同类故障样本用这个模式插补。

# %%
data_['紧急程度'].value_counts()
# Out:
# 正常       1560
# 紧急        841
# 一般        680
# 无要求       587
# 重要        400
# 1个工作日     207
# 2个工作日     136
# 3个工作日      37
# 郭帅          2
# 王老师         1
# 潘婷          1
# Name: 紧急程度, dtype: int64

# %%
data_.loc[-data_['紧急程度'].isin(['正常', '紧急', '重要', '无要求']), '紧急程度'] = '未知'

# %%
data_['紧急程度'].value_counts()
# Out:
# 未知     4445
# 正常     1560
# 紧急      841
# 无要求     587
# 重要      400
# Name: 紧急程度, dtype: int64

# %% [markdown]
# #### 维修服务内容

# %%
service_content = {'维修':'维修', '仪器故障处理':'维修', '更换配件':'维修', 
                   '仪器维护保养':'维护保养', '维护':'维护保养', '年度维护':'维护保养',
                   '项目例行巡检':'巡检','巡检':'巡检',
                   '设备性能验证':'性能验证','性能验证':'性能验证',
                   '移机':'装机/移机', '搬迁':'装机/移机','搬迁调试':'装机/移机','装机调试':'装机/移机','装机调试':'装机/移机',
                   '软件问题处理':'其他','数据分析':'其他','试剂盒性能验证':'其他'}

data_['维修服务内容'] = data_['维修服务内容'].replace().map(service_content)

# %%
data_['维修服务内容'].isnull().sum()
# Out:
# 1004

# %%
data_['维修服务内容'].fillna('待确认', inplace = True)

# %% [markdown]
# #### 设备编号

# %%
data_['设备编号'].isnull().sum()
# Out:
# 916

# %% [markdown]
# 设备编号有916个缺失，观察对应设备编号的其他信息
# 可以看到对应的编号也是缺失的
# 可以看到大多是时间较早的样本，缺失过多
# 这种情况只能通过客户名称来对应仪器型号把这个缺失值插补掉

# %%
pd.options.display.max_columns = 200

data_.loc[data_['设备编号'].isnull(), :]
# Out:
#                          服务单号                 客户名称 所在省份   客户类型 客户联系人 紧急程度  \
# 7147 2018-06-27     14:00    维修部  NaN  项目建立    装机调试   上门
# 7261 2018-09-03  08:00:00  北区维修组  NaN  项目建立     NaN   上门
# 7279 2018-06-08     09:00    维修部  NaN  项目建立    项目培训   上门
# 7379 2018-05-25       NaN    维修部  NaN  项目保障      其他  NaN
# 7458 2018-08-06  08:00:00  北区维修组  NaN   NaN     NaN  NaN
# 7546 2018-01-05       NaN    维修部  NaN  细胞遗传     NaN   上门
# 7550 2018-04-03     09:00    维修部  NaN  细胞遗传     NaN   上门
# 7553 2018-05-23     19:30    维修部  NaN  内部工作    工作整理  NaN
# 7691 2018-03-29     08:00    维修部  NaN  细胞遗传     NaN   上门
# 7692 2018-03-29     08:00    维修部  NaN  产前筛查     NaN   上门
#
#                                                    问题描述 派单主管 分配工程师    维修总费用  \
# 0                 1235仪器偶尔提示&nbsp;Tip&nbsp;In&nbsp;Air。  NaN    康迈      NaN
# 1     偶尔&nbsp;17-OHP实验提示&nbsp;Tip&nbsp;In&nbsp;Air&n...  NaN    康迈      NaN
# 2                                Lis与Leica软件对接问题。\n<br>  NaN    康迈      NaN
# 3                                           FISH扫描对焦失败。  NaN    康迈      NaN
# 4              双标实验F点偏高，400万以上；\n<br>筛查阳性率低于平时，只有2%-3%；  NaN    康迈      NaN
# 5                    GSL120黑屏重启，显卡温度高。\n<br>GSL120年度保养。  NaN    吴挺      NaN
# 6     1、加样针误报clot，不多，每次实验一两个，但客户不接受；\n<br>2、洗板机头容易堵\...  NaN   戴明路      NaN
# 7                      1235产筛实验结果，标准品第四点异常，diff偏差超过50%。  NaN    潘盛      NaN
# 8                                        GSP&nbsp;性能检测。  NaN    康迈      NaN
# 9                       近期第二次发生找不到增强液的报错\n<br>已安排杨露鉴去检查  NaN   杨露鉴      NaN
# 10    1235产筛实验，标准品D点偏低，同时，质控中值也偏低，样本中，只要是4号针加样的样本，都有...  NaN    潘盛      NaN
# 11    1、洗板机堵孔，昨日多次清洁后正常，今天又堵，清洁无效\n<br>2、最近两次实验高值质控低...  NaN    林栋      NaN
# 12                     杭州市妇产科医院2号1235仪器，联机报错，1号针注射器工作异常  NaN    康迈  24000.0
# 13              客户反映GSL120加油针不灵活；\n<br>1235做性能验证，并出具报告；  NaN    康迈      NaN
# 14    1.新筛实验有报blood&nbsp;missing的报错\n<br>2.170hp&nbs...  NaN    林栋      NaN
# 15                    1235实验过程中突然在去血片过程中出现真空错误，疑似发生严重漏气  NaN   杨露鉴      NaN
# 16    近期加样枪两次问题，一次去吸头时的up-down&nbsp;mover&nbsp;stepp...  NaN    吴挺      NaN
# 17    MB8&nbsp;扫描对焦模糊；\n<br>初步判断为显微镜Z轴磨损，待下周二与奥林帕斯售后...  NaN    康迈      NaN
# 18              KM2明场捕获图像质量不理想，要求调试参数；\n<br>3台KM系统维护保养；  NaN    王剑      NaN
# 19    客户反映最近阳性标本复查重复性下降，cv超过10%的标本增多。\n\n<br>需要仪器保养与...  NaN   徐睿超      NaN
# 20      早孕实验报错“foam&nbsp;detected”，导致不吸样，加样针涂层损坏严重，需要更换  NaN    王剑      NaN
# 21    1235&nbsp;联机报错&nbsp;epprom&nbsp;读取错误，怀疑node&nb...  NaN    林栋      NaN
# 22                                   确认空气过滤器需要更换，销售已报价。  NaN   杨露鉴   6384.0
# 23                                      维修洗板机堵，并执行年度维护；  NaN    潘盛      NaN
# 24                                            例行执行半年度维护  NaN    潘盛      NaN
# 25                                   1235 更换电脑 系统重装软件重装  NaN   徐睿超      NaN
# 26                                          执行1235半年度维护  NaN    潘盛      NaN
# 27                                           执行1235季度维护  NaN   戴明路      NaN
# 28                   GSL120底座有噪音，初步判断是风扇发出的声音，需更确认问题换风扇  NaN    吴挺      NaN
# 29                                         CDS-5通风管路清理。  NaN    林栋      NaN
# ...                                                 ...  ...   ...      ...
# 5906                                           cds5年度维护  戴明路   郑耀庭      NaN
# 5913                                     按计划前往装机GSL-120  戴明路   杨露鉴      NaN
# 5957                                            120场地确认  戴明路   王新震      NaN
# 5993                                          旧设备迁移发回公司  戴明路   杨露鉴      NaN
# 6015                               设备取放架子异常，提示架子已在在载物台上  戴明路   杨露鉴      NaN
# 6082                                        1235换新机场地确认  戴明路    林栋      NaN
# 6096                                 协助PE工程师，安装一套1235系统  戴明路   郑耀庭      NaN
# 6144                                     GSL120设备安装场地确认  戴明路   林正一      NaN
# 6263                                         质谱仪器装机场地确认  文立强   徐琪枫      NaN
# 6267                                    娄底妇幼1235+地贫年度维护  文立强   黄玉立      NaN
# 6268                                    娄底妇幼1235+地贫年度维护  文立强   黄玉立      NaN
# 6664                                      安装、调试一台CDS5设备  戴明路   杨露鉴      NaN
# 6745                            新机器第4架不滴油扫描，老机器10倍拍摄背景黑  戴明路   林正一      NaN
# 6772                                       17年数据分析反馈科室会  傅菲菲    车鑫      NaN
# 6795                                         1235安装场地确认  文立强   黄玉立      NaN
# 6960                                         安装一套1235系统  戴明路   王新震      NaN
# 6979  仪器运行过程中报trays&nbsp;were&nbsp;missing&nbsp;from...  戴明路   王新震      NaN
# 7009                    1.17年数据分析反馈科室会\n<br>2.仪器维护：更换泵油  傅菲菲    车鑫      NaN
# 7067                                       120、cds5场地确认  戴明路   郑耀庭      NaN
# 7085                                        按计划进行1235装机  戴明路   赵佳盛      NaN
# 7147                                     按计划进行仪器装机调试工作；  戴明路   王新震      NaN
# 7261                                              120装机  戴明路   杨露鉴      NaN
# 7279                     现任串联实验老师病假（孙老师），上门培训新实验老师（康老师）  傅菲菲    车鑫      NaN
# 7379                                              实验室搬家  傅菲菲   陈凌云      NaN
# 7458                                                NaN  戴明路   林正一      NaN
# 7546                                       5台review电脑安装  文立强   徐琪枫      NaN
# 7550                                         安装review电脑  文立强   徐琪枫      NaN
# 7553                                             分类整理设备  傅菲菲   陈凌云      NaN
# 7691                                            120年度维护  戴明路    林栋      NaN
# 7692                                           1235年度维护  戴明路    林栋      NaN
#
#      设备编号 设备名称             设备型号 主机序列号 装机日期 维修服务内容  \
# 0     NaN  NaN              NaN   NaN  NaN     维修
# 1     NaN  NaN              NaN   NaN  NaN     维修
# 2     NaN  NaN              NaN   NaN  NaN     维修
# 7458  NaN  NaN         1235-514   NaN  NaN     维修
# 7546  NaN  NaN   GSL-120/GSL-10   NaN  NaN    待确认
# 7550  NaN  NaN   GSL-120/GSL-10   NaN  NaN    待确认
# 7553  NaN  NaN              TQD   NaN  NaN    待确认
# 7691  NaN  NaN         1235-514   NaN  NaN   维护保养
# 7692  NaN  NaN         1235-514   NaN  NaN   维护保养
#
#                                                    故障描述  \
# 0                                            Tip In Air
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                           针有问题，进行更换。
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 5906                                           cds5年度维护
# 5913                                                NaN
# 5957                                      GSL120安装场地确认。
# 5993                                               打包运回
# 6015                                                NaN
# 6082                                                NaN
# 6096                                             装机（协助）
# 6144                                     GSL120设备安装场地确认
# 6263                                           质谱装机场地确认
# 6267                                             地贫保养维护
# 6268                                         1235年度保养维护
# 6664                                                NaN
# 6745                            新机器第4架不滴油扫描，老机器10倍拍摄背景黑
# 6772                   1、17年数据分析反馈科室会\n<br>2、孙老师脚崴，实验协助
# 6795                                                NaN
# 6960                                         安装一套1235系统
# 6979  仪器运行过程中报trays&nbsp;were&nbsp;missing&nbsp;from...
# 7009              1.17年数据分析反馈科室会&nbsp;\n<br>2.仪器维护：更换泵油
# 7067                                       120，CDS5场地确认
# 7085                              进行1235装机应对3月23日的实验室检查
# 7147                                     按计划进行仪器装机调试工作；
# 7261                                                NaN
# 7279                     现任串联实验老师病假（孙老师），上门培训新实验老师（康老师）
# 7379                                                NaN
# 7458                                         1235侧面风扇异响
# 7546                                                NaN
# 7550                                                NaN
# 7553                                                NaN
# 7691                                                NaN
# 7692                                                NaN
#
#                                                    服务报告  \
# 0       1、校准右枪Flag&nbsp;传感器位置；\n<br>2、对换左右枪；\n<br>3、待观察
# 1     1、校准右枪Tip&nbsp;Sensor压力；\n<br>2、移除空气过滤器，真空报错正常...
# 2     leica软件生成xml文件，包含病人信息及图像信息；\n<br>Lis直接调用xml文件内...
# 3           1、测试发现客户未调试好曝光时间；\n<br>2、培训客户调试曝光时间，测试扫描正常；
# 4     检查仪器Flash值为1380，反馈滤光片腐蚀；\n<br>用增强液及无水酒精清洁反馈滤光片...
# 5     问题：\n<br>GSL120黑屏，怀疑显卡故障，年度维护\n<br>处理：\n<br>到场...
# 6     检查确认仪器大概率不存在问题，首先每次实验报clot的数量减少，只有一两个，其次是报错并不集...
# 7     对四根加样针进行精度测试：P1=25.33，P2=25.17，P3=25.12，P4=25....
# 8     -&nbsp;washer&nbsp;test&nbsp;正常\n<br>-&nbsp;Me...
# 9     问题：开机自检报错，机器无法运行；\n<br>措施：1.查看历史记录，发现实验前未放置稀释杯...
# 10    对四根加样针进行精度测试，发现第四根针在加水之后针尖挂水滴；\n<br>把第四根针与第三根互...
# 11    嘉兴妇保洗板头反复堵塞，清洁洗板头、电磁阀，测试正常。右枪加样准确度测试正常，定标液测试正常...
# 12               \n<br>更换2号注射器泵，Rinse测试正常；\n<br>2板实验正常；
# 13                          清洁120加油针，调试加油针角度，校准坐标；恢复正常；
# 14    1235右枪加样时会有试剂滴出，右枪有磨损。右枪压力调整，测试正常，建议更换。洗板测试、加增...
# 15    问题：&nbsp;仪器第五板去血片报5个真空错误，第六板去血片报10个真空错误，导致操作超时...
# 16    聊城市妇幼保健院\n<br>问题：\n<br>1235右枪近期两次up-down&nbsp;...
# 17                            将扫描主机移到地面上，画面晃动减弱，图像捕获清晰；
# 18    问题：捕获时条带不清晰，保养3台显微镜。\n<br>处理：1，清洁各镜头，平台，科勒照明调整...
# 19    富阳区妇幼保健院：\n<br>1235年度维护：\n<br>1.机械测试正常；增强液加样精度...
# 20    问题：实验过程中报加样针检测到气泡错误。\n<br>处理：1，查看历史记录，发现加样针在稀释...
# 21    1235&nbsp;联机报错&nbsp;epprom&nbsp;read&nbsp;erro...
# 22          2016.1.13&nbsp;盐城市妇幼保健院&nbsp;\n<br>更换空气过滤器；
# 23    问题：新的那台洗板机洗板时候出现大量气泡；\n<br>操作：查看发现气泡是在洗液和蒸馏水汇合...
# 24    •查看历史记录，未发现报错，真空泵工作时间间隔大于两分钟；&nbsp;\n<br>•系统清洁...
# 25    合肥市妇幼保健所：\n<br>问题：1235更换新电脑\n<br>操作：1.给1235的新电...
# 26    *&nbsp;系统清洁，润滑各传导杆，机械测试通过；\n<br>*&nbsp;洗板测试通过，...
# 27    执行了1235的季度维护，1.按客户要求将eu计数值校准到116万，2.清洁废液池电磁阀，解...
# 28    问题：\n<br>GSL120工作有异响，怀疑是风扇发出\n<br>处理：\n<br>更换G...
# 29                                 清洁CDS5操作室、通风管路，测试正常。
# ...                                                 ...
# 5906                                                NaN
# 5913                                                NaN
# 5957                                                NaN
# 5993                                                NaN
# 6015                                                NaN
# 6082                                                NaN
# 6096                                                NaN
# 6144                                                NaN
# 6263                                                NaN
# 6267                                                NaN
# 6268                                                NaN
# 6664                                                NaN
# 6745                                                NaN
# 6772                                                NaN
# 6795                                                NaN
# 6960                                                NaN
# 6979                                                NaN
# 7009                                                NaN
# 7067                                                NaN
# 7085                                                NaN
# 7147                                                NaN
# 7261                                                NaN
# 7279                                                NaN
# 7379                                                NaN
# 7458                                                NaN
# 7546                                                NaN
# 7550                                                NaN
# 7553                                                NaN
# 7691                                                NaN
# 7692                                                NaN
#
#                                                    解决方案  服务工时(小时)  \
# 0                                                   NaN       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# 5                                                   NaN       NaN
# 6                                                   NaN       NaN
# 7                                                   NaN       NaN
# 8                                                   NaN       NaN
# 9                                                   NaN       NaN
# 10                                                  NaN       NaN
# 11                                                  NaN       NaN
# 12                                                  NaN       NaN
# 13                                                  NaN       NaN
# 14                                                  NaN       NaN
# 15                                                  NaN       NaN
# 16                                                  NaN       NaN
# 17                                                  NaN       NaN
# 18                                                  NaN       NaN
# 19                                                  NaN       NaN
# 20                                                  NaN       NaN
# 21                                                  NaN       NaN
# 22                                                  NaN       NaN
# 23                                                  NaN       NaN
# 24                                                  NaN       NaN
# 25                                                  NaN       NaN
# 26                                                  NaN       NaN
# 27                                                  NaN       NaN
# 28                                                  NaN       NaN
# 29                                                  NaN       NaN
# ...                                                 ...       ...
# 5906                                                NaN       4.0
# 5913                                                NaN       NaN
# 5957  1.安装场地工作台面不合格，需要定做符合要求的台面。\n2.安装场地的电压合格，需要安装一个...       1.0
# 5993                                                NaN       NaN
# 6015                                                NaN       NaN
# 6082                                                NaN       NaN
# 6096                                                NaN      24.0
# 6144                                                NaN       NaN
# 6263  1、按照场地验收单内的条件对比验收\n2、面积、电、排气、温度等都符合条件\n3、部分实验器...       1.0
# 6267                                         对地贫仪器清洁润滑。       7.0
# 6268  1，用吸尘器清灰。<br>2，按照操作流程进行保养维护。<br>3，控制电脑进service...       7.0
# 6664                                                NaN       NaN
# 6745                                                NaN       NaN
# 6772  1、17年数据报告解读。临床问题：&nbsp;\n<br>1⃣️建议制定临床样本的判读规则。...       NaN
# 6795                                                NaN       4.0
# 6960  1.组装1235设备的桌子；\n<br>2.安装1235和1297设备的各个模块；\n<br...      24.0
# 6979                                                NaN       NaN
# 7009  1.17年数据报告解读。临床回顾问题：&nbsp;\n<br>1⃣️MET和C4DC阳性率高...       NaN
# 7067  120场地尚在装修，已告知老师预留网口与16A插座\n<br>CDS5场地面积较大，已告知老...       NaN
# 7085     拆箱，安装桌子，把仪器抬上桌子推到实验室，硬件上除了加样针都装了，软件等都没装，等待后续安装      10.0
# 7147                                                NaN       NaN
# 7261                                                NaN       NaN
# 7279  1、实验预处理流程培训\n<br>2、仪器日常维护流程培训\n<br>3、上机流程培训\n<...       NaN
# 7379                                                NaN       NaN
# 7458  1.拆下异响的制冷模块\n2.更换异响风扇\n3.重新安装\n4.service-temp ...       4.0
# 7546                                                NaN      10.0
# 7550                                                NaN      12.0
# 7553                                                NaN       NaN
# 7691                                                NaN       NaN
# 7692                                                NaN       NaN
#
#                      上门日期      上门时间                 解决日期      解决时间  \
# 0                     NaN       NaN           2015-12-04       NaN
# 1                     NaN       NaN           2015-12-02       NaN
# 2                     NaN       NaN           2015-12-10       NaN
# 3                     NaN       NaN           2015-12-11       NaN
# 4                     NaN       NaN           2015-12-15       NaN
# 5                     NaN       NaN           2015-12-25       NaN
# 6                     NaN       NaN           2015-12-24       NaN
# 7                     NaN       NaN           2015-12-23       NaN
# 8                     NaN       NaN           2015-12-23       NaN
# 9                     NaN       NaN           2015-12-24       NaN
# 10                    NaN       NaN           2015-12-25       NaN
# 11                    NaN       NaN           2015-12-24       NaN
# 12                    NaN       NaN           2016-01-12       NaN
# 13                    NaN       NaN           2016-01-07       NaN
# 14                    NaN       NaN           2015-12-30       NaN
# 15                    NaN       NaN           2015-12-28       NaN
# 16                    NaN       NaN           2015-12-30       NaN
# 17                    NaN       NaN           2016-01-05       NaN
# 18                    NaN       NaN           2016-01-07       NaN
# 19                    NaN       NaN           2016-01-06       NaN
# 20                    NaN       NaN           2016-01-05       NaN
# 21                    NaN       NaN           2016-01-05       NaN
# 22                    NaN       NaN           2016-01-14       NaN
# 23                    NaN       NaN           2016-01-06       NaN
# 24                    NaN       NaN           2016-01-05       NaN
# 25                    NaN       NaN           2016-01-08       NaN
# ##### 设备编号统计

# %%
data_equip = data_.drop_duplicates(subset = '设备编号', keep = 'last')

# %%
data_.loc[data_['设备编号'] == 'TMF-GCS-2013001','装机日期']
# Out:
# 6786    NaN
# 6787    NaN
# 6788    NaN
# Name: 装机日期, dtype: object

# %%
pd.options.display.max_rows = 1200
data_equip['装机日期'] = pd.to_datetime(data_equip['装机日期'], errors = 'coerce')

data_equip[['客户名称', '设备编号', '设备型号', '主机序列号','装机日期']].sort_values(by = '客户名称')
# Out:
#                          客户名称                   设备编号                  设备型号  \
# 6705                 三明市妇幼保健院         PE-PP9-2015005             2081-0010
# 6704                 三明市妇幼保健院          PE-VT-2010001              1420-020
# 6702                 三明市妇幼保健院         WTS-QM-2016002         Quattro Micro
# 6699                 三明市妇幼保健院     BSS-2016-WTS-QM-01         Quattro Micro
# 6698                 三明市妇幼保健院      BS-2010-PKI-VD-02              1420-020
# 6697                 三明市妇幼保健院      BS-2010-PKI-WR-01              1420-020
# 6696                 三明市妇幼保健院      BS-2015-PKI-P9-02             2081-0010
# 6695                 三明市妇幼保健院      OD-2016-WTS-QM-01         Quattro Micro
# 6689                  三明市第一医院     BS-2013-LAK-GSL-05        GSL-120/GSL-10
# 6694                  三明市第一医院          PE-AD-2008004              1235-514
# 6690                  三明市第一医院     BS-2013-TMN-CDS-01                 CDS-5
# 6688                  三明市第一医院      BS-2008-PKI-AD-04              1235-514
# 4251                 上杭县妇幼保健院     BS-2016-SBA-CP2-12       Capillarys 2 FP
# 6794                 上杭县妇幼保健院     SBA-CAP2FP-2016012       Capillarys 2 FP
# 6783          上海交通大学医学院附属新华医院        TMF-GCS-2013002            GCS3000DX2
# 6779          上海交通大学医学院附属新华医院     EX-2013-Aff-SMY-01            GCS3000DX2
# 6790                上海市第一人民医院     BS-2018-TMN-CDS-02                 CDS-5
# 6785               上海市第一妇婴保健院     EX-2013-Aff-SMY-02            GCS3000DX2
# 6788               上海市第一妇婴保健院        TMF-GCS-2013001            GCS3000DX2
# 6792           上海新培晶医学检验所有限公司     BS-2016-TMN-CDS-08                 CDS-5
# 5566               东南大学附属中大医院      BS-2012-PKI-VD-04              1420-020
# 5568               东南大学附属中大医院      BS-2012-PKI-WS-01              1420-020
# 5569               东南大学附属中大医院          PE-VT-2012001              1420-020
# 5171          东营市妇幼保健计划生育服务中心      BS-2013-PKI-AD-17              1235-501
# 5577          东营市妇幼保健计划生育服务中心         PE-GSP-2018004             2021-0010
# 5583          东营市妇幼保健计划生育服务中心          PE-AD-2013017              1235-514
# 5584          东营市妇幼保健计划生育服务中心          PE-AD-2018013             1235-5220
# 5585          东营市妇幼保健计划生育服务中心          PE-VT-2013005              1420-020
# 5586          东营市妇幼保健计划生育服务中心         PE-PP9-2016011             2081-0010
# 5576          东营市妇幼保健计划生育服务中心      BS-2016-PKI-P9-07             2081-0010
# 5572                  东阳市人民医院     BS-2018-TMN-CDS-01                 CDS-5
# 5573                  东阳市人民医院      BS-2018-LAK-KM-01        CaptureStation
# 7781         中国人民解放军南京军区福州总医院      BS-2013-PKI-AD-14              1235-514
# 7771                200927        NaT
# 7765       2352099/2972073 2017-11-02
# 7766                200927 2015-08-13
# 7769               4203700        NaT
# 7541                 94647 2016-10-13
# 7536             200027940        NaT
# 7540               4203331        NaT
# 7538            KC5A557202        NaT
# 7537               4203331 2016-01-06
# 5275               4203331 2016-01-06
# 7535                 94629 2015-12-31
# 7534       2351341/2971004 2014-03-12
# 7507              20810142 2014-08-06
# 7509              20210235 2016-08-27
# 7510       2351244/2970942 2012-12-14
# 7511                400109 2015-06-25
# 7521              20210235        NaT
# 7528              QBB16666        NaT
# 7495              QBB16666 2014-07-30
# 7492               4203214 2006-07-01
# 7527              20810142        NaT
# 7523                400109        NaT
# 7526              52726700        NaT
# 4245         LX10016175403 2017-03-20
# 7531       2351244/2970942        NaT
# 7529                 47369        NaT
# 7504     00-0335（61132480） 2017-05-05
# 7489                 47369 2016-05-19
# 7545               QBC1766        NaT
# 7543                   NaN        NaT
# 7542                202269        NaT
# 5702               4203486 2010-10-14
# 5700               4203824        NaT
# 5697               4203824 2017-01-12
# 3878                 45628 2014-09-25
# 6545               2351338 2014-01-24
# 6546               2351002 2009-02-10
# 6560              20810224 2015-12-04
# 6570       2351294/2970975 2013-06-20
# 6597               QAB1871        NaT
# 6571       2351158/2970890 2011-10-17
# 6574               QBC1789 2016-04-20
# 6575              20210181 2015-12-04
# 6577              52724490 2013-11-01
# 4675               QAB1871 2012-01-04
# 6585              20810224        NaT
# 6595               2351338        NaT
# 6594       2351294/2970975        NaT
# 6591              20210181        NaT
# 6583                 45628        NaT
# 6596               QBC1789        NaT
# 6578                110357 2012-05-10
# 6600       2351158/2970890        NaT
# 6599              52724490        NaT
# 6598                110357        NaT
# 4525            KC1B409602 2012-03-02
# 6610              60000336        NaT
# 6605              60000336 2013-05-24
# 6850                WAA613        NaT
# 6286               4203267        NaT
# 6287               4203267 2007-07-05
# 6262               4203683 2014-07-01
# 6264               QCA1844        NaT
# 6265                 95066 2016-12-28
# 6260                201191 2016-02-25
# 6259       2350994；2970804 2008-11-20
# 6257       2352121/2972092 2018-03-08
# 6261                 4602S 2016-02-25
# 4099                 48009 2017-05-03

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://%s:%s@%s:3306/%s?charset=utf8' %(config.sql_user, config.sql_password, config.sql_ip, config.sql_database),echo = False)
data_equip[['客户名称', '设备编号', '设备型号', '主机序列号','装机日期']].sort_values(by = '客户名称').to_sql('equipment_id', engine, if_exists='replace',index= False)

# %% [markdown]
# 可以看到设备型号的原始数据里有些模块如1296-003可能是其他大仪器的小部件，存在标记不明确的问题，不利于我们按照设备对数据分类，需要与维修工程师沟通让他们补充修正这部分信息

# %% [markdown]
# 还有一个思路是，观察到设备编号的抬头一共有几种：
#
# BS应该是博圣，PE是PE公司
# 设备编号和设备型号没准有某种对应关系

# %% [markdown]
# 另外观察设备编号可以看到，编号并不是完全连续的，比如有BS-2004-PKI-VD-02却没见到BS-2004-PKI-VD-01，这有多种可能性，有可能是这台仪器没有对应的维修报告，顺便维护，没有大修。也有可能是早期就已经淘汰，这一问题在我们定义每台仪器现在的状态的时候，是很必要的。

# %%
data_equip['设备型号'].value_counts()
# Out:
# 1235-514                161
# 1420-020                148
# GSL-120/GSL-10          144
# 2081-0010               104
# CDS-5                    91
# 1235-5220                72
# 2021-0010                72
# TQD                      69
# GCS3000DX2               63
# Capillarys 2 FP          40
# CaptureStation           33
# 1235-501                 28
# 6000-0010                27
# Xevo TQD                 25
# luminex 200              20
# Quattro Micro            19
# 1296-026                 11
# KM1                       7
# 1296-003                  7
# GCS3000Dx2                6
# GSL-120                   5
# 1420-012                  5
# 00-0335                   4
# KM2                       4
# UPLC                      3
# TQS                       3
# 1296-0010                 3
# 6000                      2
# 5014-0020                 2
# CaptureStation(FISH)      2
# LX200                     2
# MB4                       1
# Nextseq 550AR             1
# MB8/MB4                   1
# SLAN-96S                  1
# BGI SEQ-500               1
# GSL-10                    1
# Name: 设备型号, dtype: int64

# %% [markdown]
# 定义设备型号是要解决几个问题：
# 1. 存在部分样本设备型号缺失的情况，这部分缺失型号的样本对应的是哪台仪器
# 2. 计划模型的结果为预测下一次仪器维护的时间，需要将训练样本对仪器做分类，设备型号定义了这一分类

# %% [raw]
# data_.loc[data_['设备型号'] == '1235-514', ['客户名称', '设备编号', '设备型号', '主机序列号','装机日期','问题描述','实际问题描述']]

# %% [markdown]
# #### 日期时间处理
#
# 1. 问题发现日期和解决日期是全的，但是服务小时跟上门日期有关，这部分是未知的
# 2. 缺失了服务小时的样本跟设备编号的缺失是对应的，这部分数据插补较困难，属于下一步的工作，可以先做设备编号全的数据

# %%
import missingno as msno
msno.matrix(data_[['设备编号','问题发现日期', '装机日期', '服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# ##### 装机日期

# %%
zjrq_dict = data_equip['装机日期']
zjrq_dict.index = data_equip['设备编号']
zjrq_dict = zjrq_dict.to_dict()

# %%
data = data_.loc[data_['设备编号'].notnull(),:].reset_index(drop = True)

data['装机日期'] = data['设备编号'].map(zjrq_dict)

# %% [markdown]
# 可以看到使用设备编号的映射来插补装机日期时，也没有多少的改进，大部分缺失的依然是缺失的

# %%
msno.matrix(data[['设备编号','问题发现日期', '装机日期','服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# 接下来用解决日期和上门日期来修正服务小时
#
# 可以看到缺失的条数并不多，并且能被插补的也并不多

# %% [markdown]
# ##### 服务工时
#
# 用来衡量问题的解决难度

# %%
data.loc[data['服务工时(小时)'].isnull(),['上门日期','上门时间','解决日期','解决时间']]
# Out:
#                      上门日期      上门时间                 解决日期      解决时间
# 43             2016-08-28       NaN                  NaN       NaN
# 107            2016-09-19       NaN                  NaN       NaN
# 112            2016-09-21       NaN                  NaN       NaN
# 118            2016-09-24       NaN                  NaN       NaN
# 121            2016-09-24       NaN                  NaN       NaN
# 122            2016-09-24       NaN                  NaN       NaN
# 130            2016-10-09       NaN                  NaN       NaN
# 133            2016-10-10       NaN                  NaN       NaN
# 169            2016-10-26       NaN                  NaN       NaN
# 905            2017-04-26       NaN           2017-04-27       NaN
# 1354                  NaN       NaN                  NaN       NaN
# 1434                  NaN       NaN                  NaN       NaN
# 1435                  NaN       NaN                  NaN       NaN
# 1514                  NaN       NaN                  NaN       NaN
# 1917                  NaN       NaN                  NaN       NaN
# 2475                  NaN       NaN                  NaN       NaN
# 3235           2017-04-26       NaN           2017-04-27       NaN
# 3684                  NaN       NaN                  NaN       NaN
# 3764                  NaN       NaN                  NaN       NaN
# 3765                  NaN       NaN                  NaN       NaN
# 3844                  NaN       NaN                  NaN       NaN
# 4247                  NaN       NaN                  NaN       NaN
# 4792                  NaN       NaN                  NaN       NaN
# 4993                  NaN       NaN                  NaN       NaN
# 4994                  NaN       NaN                  NaN       NaN
# 5162  2018-09-05 00:00:00  15:00:00  2018-09-05 00:00:00  16:00:00
# 5311                  NaN     08:00                  NaN     08:00
# 5381                  NaN       NaN                  NaN       NaN
# 5405                  NaN       NaN                  NaN       NaN
# 5428                  NaN       NaN                  NaN       NaN
# 5499                  NaN       NaN                  NaN       NaN
# 5786  2018-09-06 00:00:00  08:30:00  2018-09-06 00:00:00  08:30:00
# 5809                  NaN       NaN                  NaN       NaN
# 5886                  NaN       NaN                  NaN       NaN
# 6123  2018-08-17 00:00:00  08:00:00  2018-08-17 00:00:00  11:00:00
# 6124  2018-09-04 00:00:00  13:30:00  2018-09-04 00:00:00  14:00:00
# 6201                  NaN       NaN                  NaN       NaN
# 6202                  NaN       NaN                  NaN       NaN
# 6322                  NaN       NaN                  NaN       NaN
# 6337                  NaN       NaN                  NaN       NaN
# 6427  2018-09-11 00:00:00  13:30:00  2018-09-11 00:00:00  17:30:00
# 6560                  NaN       NaN                  NaN       NaN
# 6721  2018-08-29 00:00:00  14:00:00  2018-08-29 00:00:00  17:00:00
# 6722  2018-08-28 00:00:00  09:30:00                  NaN       NaN
# 6723                  NaN       NaN                  NaN       NaN
# 6726                  NaN       NaN                  NaN       NaN
# 6727                  NaN       NaN                  NaN       NaN
# 6728                  NaN       NaN                  NaN       NaN
# 6834                  NaN       NaN                  NaN       NaN
# 6842  2018-09-13 00:00:00  09:00:00  2018-09-13 00:00:00  14:30:00

# %%
data.loc[5162,'服务工时(小时)'] = 1
data.loc[6123,'服务工时(小时)'] = 3
data.loc[6124,'服务工时(小时)'] = 0.5
data.loc[6427,'服务工时(小时)'] = 4
data.loc[6721,'服务工时(小时)'] = 3
data.loc[6842,'服务工时(小时)'] = 5.5

# %% [markdown]
# ##### 服务间隔
#
# 用来衡量这个问题的紧急程度，问题可能导致第二天就无法做实验的就会立即派工程师去
# 这个特征跟客户的重要程度和到客户的距离可能会有关，可以研究一下
#
# 还能发现一些脏数据的位置

# %% [markdown]
# 问题发现日期很多是瞎填的，作为绩效考核指标，所以他们通常会填写上门日期的前几天，所以并不一定是准确的，只能作为参考
# 服务单号的日期编码是自动生成的，和报告提交日期一致

# %%
data['服务间隔天数'] = (pd.to_datetime(data['上门日期'], errors = 'coerce') - pd.to_datetime(data['问题发现日期'], errors = 'coerce')).apply(lambda x: x.days)

# %% [markdown]
# ##### 上次维修时间
#
# 对于一台设备，上一次维修时间是被记录的，如果只有一条记录，就登记为空

# %%
from tqdm import tqdm_notebook

data['上次维修时间'] = data['问题发现日期'].copy()
def last_service(x):
    del x[-1]
    x.insert(0, None)
    return x
for equipment_id in tqdm_notebook(data['设备编号'].unique()):
    cache = list(data.loc[data['设备编号'] == equipment_id, '问题发现日期'])
    if len(cache) <= 1:
        data.loc[data['设备编号'] == equipment_id, '上次维修时间'] = None
    else:
        data.loc[data['设备编号'] == equipment_id, '上次维修时间'] = last_service(cache)
# Out:
# HBox(children=(IntProgress(value=0, max=1189), HTML(value='')))

# %%
msno.matrix(data[['设备编号','问题发现日期','上次维修时间', '装机日期','服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# 由于很多仪器是刚装的，第一次维修，所以装机日期来替代上次维修时间是合理的
# 需要考虑的是，第一次新机其实对于相同的问题来说，新机应该是更难坏的，需要留一个标签记录

# %%
data['问题发现日期'].min()
# Out:
# Timestamp('2016-06-30 00:00:00')

# %%
data['装机日期'] = pd.to_datetime(data['装机日期'], errors = 'coerce')

data.loc[(data['上次维修时间'].isnull())&(data['装机日期'] > '2016-06-30'),'上次维修时间'] = data.loc[(data['上次维修时间'].isnull())&(data['装机日期'] > '2016-06-30'),'装机日期']

# %%
msno.matrix(data[['设备编号','问题发现日期','上次维修时间', '装机日期','服务工时(小时)', '上门日期', '解决日期']],figsize=(16, 10),color=(0.7, 0.1, 0.1),filter='bottom',sparkline=False)

# %% [markdown]
# #### 文本处理

# %%
import re

def text_clean(content):
    try:
#         result = re.sub(r'[^\u4e00-\u9fa5,A-Za-z0-9]', " ",content)
        result = re.sub('&nbsp;', "",content)
        result = re.sub('<br>', "",result)
        result = re.sub(' ', "",result)
#         result = re.sub('正常', " ",result)
        result = re.sub('\n', "",result)
        result = re.sub('\t', "",result)
    except:
        result = ''
    return result

# %%
for col in ['问题描述', '故障描述','服务报告','解决方案','实际问题描述']:
    data[col] = data[col].apply(text_clean)

# %% [markdown]
# 电脑故障不属于定期维护范围之内，后期可以不做考虑。如serverBusy问题

# %% [markdown]
# 可以看到问题描述，故障描述，实际问题描述有重复的部分，服务报告解决方案可能也有重复的部分

# %% [markdown]
# ##### 文本去重 余弦相似性

# %%
from jieba import analyse

def words2vec(words1=None, words2=None):
    """
    通过分词、计算并集、词频，得出词频向量
    :param words1:
    :param words2:
    :return: 词频的向量
    """
    v1 = []
    v2 = []
    tag1 = analyse.extract_tags(words1, withWeight=True)
    tag2 = analyse.extract_tags(words2, withWeight=True)
    tag_dict1 = {i[0]: i[1] for i in tag1}
    tag_dict2 = {i[0]: i[1] for i in tag2}
    merged_tag = set(tag_dict1.keys()) | set(tag_dict2.keys())
    for i in merged_tag:
        if i in tag_dict1:
            v1.append(tag_dict1[i])
        else:
            v1.append(0)
        if i in tag_dict2:
            v2.append(tag_dict2[i])
        else:
            v2.append(0)
    return v1, v2

def cosine_similarity(vector1, vector2):
    """
    余弦值相似度计算
    :param vector1:
    :param vector2:
    :return:
    """

    dot_product = 0.0
    norm1 = 0.0
    norm2 = 0.0
    for a, b in zip(vector1, vector2):
        dot_product += a * b
        norm1 += a ** 2
        norm2 += b ** 2
    if norm1 == 0.0 or norm2 == 0.0:
        return 0
    else:
        return round(dot_product / ((norm1 ** 0.5) * (norm2 ** 0.5)) * 100, 2)

# %%
_data = data.copy()

from tqdm import trange

def cosine_calculator(_data, col1, col2):
    cosine_sim = []
    for i in range(_data.shape[0]):
        w2v1, w2v2 = words2vec(_data[col1][i],_data[col2][i])
        cosine_sim.append(cosine_similarity(w2v1,w2v2))
    return cosine_sim 

def text_col_len(series):
    return series.apply(lambda x: len(x))

def text_concat(data, cut_value, col1, col2):
    _data = data.copy()
    cosine_sim = cosine_calculator(_data, col1, col2)
    _data['cosine_sim'] = cosine_sim
    _data['{}_len'.format(col1)] = text_col_len(_data[col1])
    _data['{}_len'.format(col2)] = text_col_len(_data[col2])
    _data['output'] = None
    _data.loc[_data['cosine_sim'] <=cut_value, 'output'] = _data.loc[_data['cosine_sim'] <=cut_value, col1] + _data.loc[_data['cosine_sim'] <cut_value,col2]
    _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] >= _data['{}_len'.format(col2)]), 'output'] = _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] >= _data['{}_len'.format(col2)]),col1]
    _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] < _data['{}_len'.format(col2)]), 'output'] = _data.loc[(_data['cosine_sim'] >cut_value)&(_data['{}_len'.format(col1)] < _data['{}_len'.format(col2)]),col2]
    return _data['output']

_data['问题汇总1'] = text_concat(_data, 85, '问题描述', '故障描述')
_data['问题汇总'] = text_concat(_data, 85, '问题汇总1', '实际问题描述')

data['问题汇总'] = _data['问题汇总'].copy()
data['解决方案汇总'] = text_concat(data, 85, '服务报告','解决方案')

# %% [markdown]
# ### 提取有用字段

# %%
data.columns
# Out:
# Index(['服务单号', '客户名称', '所在省份', '客户类型', '客户联系人', '紧急程度', '问题发现日期', '问题发现时间',
#        '服务部门', '事项 ', '项目类别', '分项内容', '工作方式', '问题描述', '派单主管', '分配工程师', '维修总费用',
#        '设备编号', '设备名称', '设备型号', '主机序列号', '装机日期', '维修服务内容', '故障描述', '服务报告',
#        '解决方案', '服务工时(小时)', '上门日期', '上门时间', '解决日期', '解决时间', '总结提交日期', '任务星级',
#        '实际问题描述', '回访时间', '回访对象', '问题是否解决', '总体满意度', '礼仪/形象', '技能水平', '沟通能力',
#        '服务态度', '服务间隔天数', '上次维修时间', '解决方案汇总'],
#       dtype='object')

# %%
data[['服务单号', '客户名称', '客户类型', '紧急程度', '问题发现日期', '分配工程师', 
      '设备编号', '设备型号','服务工时(小时)', '服务间隔天数', '上次维修时间',
      '装机日期', '维修服务内容', '问题汇总', '解决方案汇总']].to_sql('etl_data', engine, if_exists='replace',index= False)
